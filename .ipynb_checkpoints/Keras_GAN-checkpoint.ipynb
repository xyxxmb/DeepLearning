# %%
# 参考网址 https://mp.weixin.qq.com/s?__biz=MzA3MzI4MjgzMw==&mid=2650731540&idx=1&sn=193457603fe11b89f3d298ac1799b9fd&chksm=871b306ab06cb97c502af9552657b8e73f1f5286bc4cc71b021f64604fd53dae3f026bc9ac69&mpshare=1&scene=23&srcid=12158jtIOgd23oyZM7eTgUrZ#rd

# %%
from keras.models import Sequential
from keras.layers import Dense
from keras.layers import Reshape
from keras.layers.core import Activation
from keras.layers.normalization import BatchNormalization
from keras.layers.convolutional import UpSampling2D
from keras.layers.convolutional import Conv2D, MaxPooling2D
from keras.layers.core import Flatten
from keras.optimizers import SGD
from keras.datasets import mnist
import numpy as np
from PIL import Image
import argparse
import math
# Out:
# Using TensorFlow backend.

# %% [markdown]
# 整个训练过程可以说判别器 D 和生成器 G 对价值函数 V(G,D) 进行了极小极大化博弈：
# ![gan_tf_keras1.png](./Res/gan_tf_keras1.png)

# %% [markdown]
# ### 最优生成器
#
# 因为最优的判别器D(x)=P_data/(P_data+P_G)，我们将其代入V（G,D）可得：
# ![gan_tf_keras2.png](./Res/gan_tf_keras2.png)
# 该积分进行变换得：
# ![gan_tf_keras3.png](./Res/gan_tf_keras3.png)
# 假设存在两个分布 P 和 Q，且这两个分布的平均分布 M=(P+Q)/2，那么这两个分布之间的 JS 散度为 P 与 M 之间的 KL 散度加上 Q 与 M 之间的 KL 散度再除以 2；因此可化为：
# ![gan_tf_keras4.png](./Res/gan_tf_keras4.png)
#
# JS 散度的取值为 0 到 log2。若两个分布完全没有交集，那么 JS 散度取最大值 log2；若两个分布完全一样，那么 JS 散度取最小值 0。当 P_G=P_data 时，JSD(P_data||P_G) 为 0。综上所述，生成分布当且仅当等于真实数据分布式时，我们可以取得最优生成器。

# %%
def generator_model():
    #下面搭建生成器的架构，首先导入序贯模型（sequential），即多个网络层的线性堆叠
    model = Sequential()
    #添加一个全连接层，输入为100维向量，输出为1024维
    model.add(Dense(input_dim=100, output_dim=1024))
    #添加一个激活函数tanh
    model.add(Activation('tanh'))
    #添加一个全连接层，输出为128×7×7维度
    model.add(Dense(128*7*7))
    #添加一个批量归一化层，该层在每个batch上将前一层的激活值重新规范化，即使得其输出数据的均值接近0，其标准差接近1
    model.add(BatchNormalization())
    model.add(Activation('tanh'))
    #Reshape层用来将输入shape转换为特定的shape，将含有128*7*7个元素的向量转化为7×7×128张量
    model.add(Reshape((7, 7, 128), input_shape=(128*7*7,)))
    #2维上采样层，即将数据的行和列分别重复2次
    model.add(UpSampling2D(size=(2, 2)))
    #添加一个2维卷积层，卷积核大小为5×5，激活函数为tanh，共64个卷积核，并采用padding以保持图像尺寸不变
    model.add(Conv2D(64, (5, 5), padding='same'))
    model.add(Activation('tanh'))
    model.add(UpSampling2D(size=(2, 2)))
    #卷积核设为1即输出图像的维度
    model.add(Conv2D(1, (5, 5), padding='same'))
    model.add(Activation('tanh'))
    return model

# %% [markdown]
# ### 最优判别器
#
# 原论文中价值函数可写为在 x 上的积分，即将数学期望展开为积分形式：
# ![gan_tf_keras5.png](./Res/gan_tf_keras5.png)
# 其实求积分的最大值可以转化为求被积函数的最大值。而求被积函数的最大值是为了求得最优判别器 D，因此不涉及判别器的项都可以看作为常数项。
# 若令判别器 D(x) 等于 y，那么被积函数可以写为：
# ![gan_tf_keras6.png](./Res/gan_tf_keras6.png)
# 为了找到最优的极值点，如果 a+b≠0，我们可以用以下一阶导求解：
# ![gan_tf_keras6.png](./Res/gan_tf_keras7.png)
# 因此，最优判别器D(x)=P_data/(P_data+P_G)

# %%
def discriminator_model():
    #下面搭建判别器架构，同样采用序贯模型
    model = Sequential()
    
    #添加2维卷积层，卷积核大小为5×5，激活函数为tanh，输入shape在‘channels_first’模式下为（samples,channels，rows，cols）
    #在‘channels_last’模式下为（samples,rows,cols,channels），输出为64维
    model.add(
            Conv2D(64, (5, 5),
            padding='same',
            input_shape=(28, 28, 1))
            )
    model.add(Activation('tanh'))
    #为空域信号施加最大值池化，pool_size取（2，2）代表使图片在两个维度上均变为原长的一半
    model.add(MaxPooling2D(pool_size=(2, 2)))
    model.add(Conv2D(128, (5, 5)))
    model.add(Activation('tanh'))
    model.add(MaxPooling2D(pool_size=(2, 2)))
    #Flatten层把多维输入一维化，常用在从卷积层到全连接层的过渡
    model.add(Flatten())
    model.add(Dense(1024))
    model.add(Activation('tanh'))
    #一个结点进行二值分类，并采用sigmoid函数的输出作为概念
    model.add(Dense(1))
    model.add(Activation('sigmoid'))
    return model

# %%
def generator_containing_discriminator(g, d):
    #将前面定义的生成器架构和判别器架构组拼接成一个大的神经网络，用于判别生成的图片
    model = Sequential()
    #先添加生成器架构，再令d不可训练，即固定d
    #因此在给定d的情况下训练生成器，即通过将生成的结果投入到判别器进行辨别而优化生成器
    model.add(g)
    d.trainable = False
    model.add(d)
    return model

# %%
def combine_images(generated_images):
    #生成图片拼接
    num = generated_images.shape[0]
    width = int(math.sqrt(num))
    height = int(math.ceil(float(num)/width))
    shape = generated_images.shape[1:3]
    image = np.zeros((height*shape[0], width*shape[1]),
                     dtype=generated_images.dtype)
    for index, img in enumerate(generated_images):
        i = int(index/width)
        j = index % width
        image[i*shape[0]:(i+1)*shape[0], j*shape[1]:(j+1)*shape[1]] = \
            img[:, :, 0]
    return image

# %% [markdown]
# #### 对于每一次迭代：
#
# -  从真实数据分布 P_data 抽取 m 个样本
# -  从先验分布 P_prior(z) 抽取 m 个噪声样本
# -  将噪声样本投入 G 而生成数据，即x^tilde = G(Z^i)；通过最大化 V 的近似而更新判别器参数θ_d
#
# 以上是学习判别器 D 的过程。因为学习 D 的过程是计算 JS 散度的过程，并且我们希望能最大化价值函数，所以该步骤会重复 k 次。
#
# -  从先验分布 P_prior(z) 中抽取另外 m 个噪声样本 {z^1,...,z^m}
# -  通过极小化 V^tilde 而更新生成器参数θ_g

# %%
def train(BATCH_SIZE):
    
    # 国内好像不能直接导入数据集，我们试了几次都不行，后来将数据集下载到本地'~/.keras/datasets/'，也就是当前目录（我的是用户文件夹下）下的.keras文件夹中。
    #下载的地址为：https://s3.amazonaws.com/img-datasets/mnist.npz
    (X_train, y_train), (X_test, y_test) = mnist.load_data()
    #image_data_format选择"channels_last"或"channels_first"，该选项指定了Keras将要使用的维度顺序。
    #"channels_first"假定2D数据的维度顺序为(channels, rows, cols)，3D数据的维度顺序为(channels, conv_dim1, conv_dim2, conv_dim3)
    
    X_train = (X_train.astype(np.float32) - 127.5)/127.5
    # print(np.shape(X_train))   # (60000, 28, 28)
    X_train = X_train[:, :, :, None]   # None将3维的X_train扩展为4维
    X_test = X_test[:, :, :, None]
    # X_train = X_train.reshape((X_train.shape, 1) + X_train.shape[1:])
    
    #将定义好的模型架构赋值给特定的变量
    d = discriminator_model()
    g = generator_model()
    d_on_g = generator_containing_discriminator(g, d)
    
    #定义生成器模型判别器模型更新所使用的优化算法及超参数
    d_optim = SGD(lr=0.001, momentum=0.9, nesterov=True)
    g_optim = SGD(lr=0.001, momentum=0.9, nesterov=True)
    
    #编译三个神经网络并设置损失函数和优化算法，其中损失函数都是用的是二元分类交叉熵函数。编译是用来配置模型学习过程的
    g.compile(loss='binary_crossentropy', optimizer="SGD")
    d_on_g.compile(loss='binary_crossentropy', optimizer=g_optim)
    
    #前一个架构在固定判别器的情况下训练了生成器，所以在训练判别器之前先要设定其为可训练。
    d.trainable = True
    d.compile(loss='binary_crossentropy', optimizer=d_optim)
    
    #下面在满足epoch条件下进行训练
    for epoch in range(30):
        print("Epoch is", epoch)
        
        #计算一个epoch所需要的迭代数量，即训练样本数除批量大小数的值取整；其中shape[0]就是读取矩阵第一维度的长度
        print("Number of batches", int(X_train.shape[0]/BATCH_SIZE))
        
        #在一个epoch内进行迭代训练
        for index in range(int(X_train.shape[0]/BATCH_SIZE)):
            
            #随机生成的噪声服从均匀分布，且采样下界为-1、采样上界为1，输出BATCH_SIZE×100个样本；即抽取一个批量的随机样本
            noise = np.random.uniform(-1, 1, size=(BATCH_SIZE, 100))
            
            #抽取一个批量的真实图片
            image_batch = X_train[index*BATCH_SIZE:(index+1)*BATCH_SIZE]
            
            #生成的图片使用生成器对随机噪声进行推断；verbose为日志显示，0为不在标准输出流输出日志信息，1为输出进度条记录
            generated_images = g.predict(noise, verbose=0)
            
            #每经过100次迭代输出一张生成的图片
            if index % 100 == 0:
                image = combine_images(generated_images)
                image = image*127.5+127.5
                Image.fromarray(image.astype(np.uint8)).save(
                    "./GAN/"+str(epoch)+"_"+str(index)+".png")
            
            #将真实的图片和生成的图片以多维数组的形式拼接在一起，真实图片在上，生成图片在下
            X = np.concatenate((image_batch, generated_images))
            
            #生成图片真假标签，即一个包含两倍批量大小的列表；前一个批量大小都是1，代表真实图片，后一个批量大小都是0，代表伪造图片
            y = [1] * BATCH_SIZE + [0] * BATCH_SIZE
            
            #判别器的损失；在一个batch的数据上进行一次参数更新
            d_loss = d.train_on_batch(X, y)
            print("batch %d d_loss : %f" % (index, d_loss))  # 理论上，d的loss越来越大，因为生成图片和真实图片越来越像
            
            #随机生成的噪声服从均匀分布
            noise = np.random.uniform(-1, 1, (BATCH_SIZE, 100))
            
            #固定判别器
            d.trainable = False
            
            #计算生成器损失；在一个batch的数据上进行一次参数更新
            g_loss = d_on_g.train_on_batch(noise, [1] * BATCH_SIZE)
            
            #令判别器可训练
            d.trainable = True
            print("batch %d g_loss : %f" % (index, g_loss)) # 理论上，g的loss越来越小，因为生成图像越接近真实，生成图像的label接近1
            
            #每100次迭代保存一次生成器和判别器的权重
            if index % 100 == 9:
                g.save_weights('generator', True)
                d.save_weights('discriminator', True)

# %%
def generate(BATCH_SIZE, nice= False ):
    #训练完模型后，可以运行该函数生成图片
    g = generator_model()
    g.compile(loss='binary_crossentropy', optimizer="SGD")
    g.load_weights('generator')
    if nice:
        d = discriminator_model()
        d.compile(loss='binary_crossentropy', optimizer="SGD")
        d.load_weights('discriminator')
        noise = np.random.uniform(-1, 1, (BATCH_SIZE*20, 100))
        generated_images = g.predict(noise, verbose=1)
        d_pret = d.predict(generated_images, verbose=1)
        index = np.arange(0, BATCH_SIZE*20)
        index.resize((BATCH_SIZE*20, 1))
        pre_with_index = list(np.append(d_pret, index, axis=1))
        pre_with_index.sort(key=lambda x: x[0], reverse=True)
        nice_images = np.zeros((BATCH_SIZE,) + generated_images.shape[1:3], dtype=np.float32)
        nice_images = nice_images[:, :, :, None]
        for i in range(BATCH_SIZE):
            idx = int(pre_with_index[i][1])
            nice_images[i, :, :, 0] = generated_images[idx, :, :, 0]
        image = combine_images(nice_images)
    else:
        noise = np.random.uniform(-1, 1, (BATCH_SIZE, 100))
        generated_images = g.predict(noise, verbose=0)
        image = combine_images(generated_images)
    image = image*127.5+127.5
    Image.fromarray(image.astype(np.uint8)).save(
        "./GAN/generated_image5.png")

# %%
# train(100)
# Out:
# D:\Anaconda3\envs\tensorflow\lib\site-packages\ipykernel_launcher.py:5: UserWarning: Update your `Dense` call to the Keras 2 API: `Dense(input_dim=100, units=1024)`
#   """
# Epoch is 0
# Number of batches 600
# batch 0 d_loss : 0.715787
# batch 0 g_loss : 0.585973
# batch 1 d_loss : 0.693202
# batch 1 g_loss : 0.580978
# batch 2 d_loss : 0.661997
# batch 2 g_loss : 0.568749
# batch 3 d_loss : 0.632390
# batch 3 g_loss : 0.560257
# batch 4 d_loss : 0.604880
# batch 4 g_loss : 0.547050
# batch 5 d_loss : 0.570920
# batch 5 g_loss : 0.539678
# batch 6 d_loss : 0.552264
# batch 6 g_loss : 0.523507
# batch 7 d_loss : 0.530804
# batch 7 g_loss : 0.518388
# batch 8 d_loss : 0.513476
# batch 8 g_loss : 0.511915
# batch 9 d_loss : 0.491013
# batch 9 g_loss : 0.502258
# batch 10 d_loss : 0.478356
# batch 10 g_loss : 0.497371
# batch 11 d_loss : 0.466117
# batch 11 g_loss : 0.491710
# batch 12 d_loss : 0.469587
# batch 12 g_loss : 0.486973
# batch 13 d_loss : 0.467601
# batch 13 g_loss : 0.480791
# batch 14 d_loss : 0.454977
# batch 14 g_loss : 0.480441
# batch 15 d_loss : 0.450975
# batch 15 g_loss : 0.478497
# batch 16 d_loss : 0.451622
# batch 16 g_loss : 0.477151
# batch 17 d_loss : 0.450782
# batch 17 g_loss : 0.472900
# batch 18 d_loss : 0.456129
# batch 18 g_loss : 0.477866
# batch 19 d_loss : 0.464744
# batch 19 g_loss : 0.478355
# batch 20 d_loss : 0.467525
# batch 20 g_loss : 0.470800
# batch 21 d_loss : 0.471828
# batch 21 g_loss : 0.484534
# batch 22 d_loss : 0.475946
# batch 22 g_loss : 0.493827
# batch 23 d_loss : 0.479144
# batch 23 g_loss : 0.494265
# batch 24 d_loss : 0.484440
# batch 24 g_loss : 0.505147
# batch 25 d_loss : 0.493041
# batch 25 g_loss : 0.502922
# batch 26 d_loss : 0.498248
# batch 26 g_loss : 0.512501
# batch 27 d_loss : 0.505269
# batch 27 g_loss : 0.516652
# batch 28 d_loss : 0.510035
# batch 28 g_loss : 0.527096
# batch 29 d_loss : 0.505527
# batch 29 g_loss : 0.544841
# batch 30 d_loss : 0.498780
# batch 30 g_loss : 0.557752
# batch 31 d_loss : 0.502986
# batch 31 g_loss : 0.575302
# batch 32 d_loss : 0.495582
# batch 32 g_loss : 0.588987
# batch 33 d_loss : 0.499563
# batch 33 g_loss : 0.603641
# batch 34 d_loss : 0.495965
# batch 34 g_loss : 0.626511
# batch 35 d_loss : 0.497825
# batch 35 g_loss : 0.641622
# batch 36 d_loss : 0.497919
# batch 36 g_loss : 0.666872
# batch 37 d_loss : 0.490341
# batch 37 g_loss : 0.701513
# batch 38 d_loss : 0.475554
# batch 38 g_loss : 0.705882
# batch 39 d_loss : 0.465646
# batch 39 g_loss : 0.728856
# batch 40 d_loss : 0.465050
# batch 40 g_loss : 0.748591
# batch 41 d_loss : 0.448356
# batch 41 g_loss : 0.782554
# batch 42 d_loss : 0.453142
# batch 42 g_loss : 0.792100
# batch 43 d_loss : 0.433053
# batch 43 g_loss : 0.815823
# batch 44 d_loss : 0.429088
# batch 44 g_loss : 0.829673
# batch 45 d_loss : 0.420023
# batch 45 g_loss : 0.852230
# batch 46 d_loss : 0.403055
# batch 46 g_loss : 0.862521
# batch 47 d_loss : 0.422839
# batch 47 g_loss : 0.884572
# batch 48 d_loss : 0.405635
# batch 48 g_loss : 0.891548
# batch 49 d_loss : 0.380431
# batch 49 g_loss : 0.901135
# batch 50 d_loss : 0.355863
# batch 50 g_loss : 0.921758
# batch 51 d_loss : 0.346296
# batch 51 g_loss : 0.923403
# batch 52 d_loss : 0.323466
# batch 52 g_loss : 0.928741
# batch 53 d_loss : 0.319107
# batch 53 g_loss : 0.937313
# batch 54 d_loss : 0.296178
# batch 54 g_loss : 0.949125
# batch 55 d_loss : 0.288834
# batch 55 g_loss : 0.936814
# batch 56 d_loss : 0.283058
# batch 56 g_loss : 0.961968
# batch 57 d_loss : 0.272037
# batch 57 g_loss : 0.968292
# batch 58 d_loss : 0.259205
# batch 58 g_loss : 0.961596
# batch 59 d_loss : 0.239365
# batch 59 g_loss : 0.962823
# batch 60 d_loss : 0.222795
# batch 60 g_loss : 0.972585
# batch 61 d_loss : 0.211404
# batch 61 g_loss : 0.950755
# batch 62 d_loss : 0.203786
# batch 62 g_loss : 0.950254
# batch 63 d_loss : 0.205887
# batch 63 g_loss : 0.932736
# batch 64 d_loss : 0.219629
# batch 64 g_loss : 0.891904
# batch 65 d_loss : 0.209361
# batch 65 g_loss : 0.907711
# batch 66 d_loss : 0.209682
# batch 66 g_loss : 0.873584
# batch 67 d_loss : 0.246262
# batch 67 g_loss : 0.861838
# batch 68 d_loss : 0.209045
# batch 68 g_loss : 0.817446
# batch 69 d_loss : 0.180820
# batch 69 g_loss : 0.757666
# batch 70 d_loss : 0.205770
# batch 70 g_loss : 0.750376
# batch 71 d_loss : 0.205714
# batch 71 g_loss : 0.710363
# batch 72 d_loss : 0.229390
# batch 72 g_loss : 0.659557
# batch 73 d_loss : 0.254133
# batch 73 g_loss : 0.623708
# batch 74 d_loss : 0.213638
# batch 74 g_loss : 0.585036
# batch 75 d_loss : 0.209821
# batch 75 g_loss : 0.568622
# batch 76 d_loss : 0.222631
# batch 76 g_loss : 0.512706
# batch 77 d_loss : 0.214193
# batch 77 g_loss : 0.541090
# batch 78 d_loss : 0.211441
# batch 78 g_loss : 0.480658
# batch 79 d_loss : 0.218969
# batch 79 g_loss : 0.471060
# batch 80 d_loss : 0.235283
# batch 80 g_loss : 0.476245
# batch 81 d_loss : 0.246739
# batch 81 g_loss : 0.441354
# batch 82 d_loss : 0.251209
# batch 82 g_loss : 0.443685
# batch 83 d_loss : 0.245064
# batch 83 g_loss : 0.422866
# batch 84 d_loss : 0.252165
# batch 84 g_loss : 0.423105
# batch 85 d_loss : 0.247992
# batch 85 g_loss : 0.421319
# batch 86 d_loss : 0.263611
# batch 86 g_loss : 0.407709
# batch 87 d_loss : 0.253067
# batch 87 g_loss : 0.417050
# batch 88 d_loss : 0.273844
# batch 88 g_loss : 0.436851
# batch 89 d_loss : 0.287282
# batch 89 g_loss : 0.418433
# batch 90 d_loss : 0.308111
# batch 90 g_loss : 0.468746
# batch 91 d_loss : 0.325613
# batch 91 g_loss : 0.443551
# batch 92 d_loss : 0.345060
# batch 92 g_loss : 0.469437
# batch 93 d_loss : 0.291320
# batch 93 g_loss : 0.504188
# batch 94 d_loss : 0.338832
# batch 94 g_loss : 0.524820
# batch 95 d_loss : 0.287943
# batch 95 g_loss : 0.576287
# batch 96 d_loss : 0.285921
# batch 96 g_loss : 0.616211
# batch 97 d_loss : 0.263754
# batch 97 g_loss : 0.640262
# batch 98 d_loss : 0.282341
# batch 98 g_loss : 0.673718
# batch 99 d_loss : 0.268676
# batch 99 g_loss : 0.737820
# batch 100 d_loss : 0.234713
# batch 100 g_loss : 0.825293
# batch 101 d_loss : 0.230277
# batch 101 g_loss : 0.904083
# batch 102 d_loss : 0.205882
# batch 102 g_loss : 0.996857
# batch 103 d_loss : 0.214216
# batch 103 g_loss : 1.063849
# batch 104 d_loss : 0.172954
# batch 104 g_loss : 1.175312
# batch 105 d_loss : 0.166738
# batch 105 g_loss : 1.286341
# batch 106 d_loss : 0.167153
# batch 106 g_loss : 1.412997
# batch 107 d_loss : 0.147470
# batch 107 g_loss : 1.474370
# batch 108 d_loss : 0.123753
# batch 108 g_loss : 1.572266
# batch 109 d_loss : 0.123897
# batch 109 g_loss : 1.769499
# batch 110 d_loss : 0.118430
# batch 110 g_loss : 1.782984
# batch 111 d_loss : 0.105425
# batch 111 g_loss : 1.886929
# batch 112 d_loss : 0.106170
# batch 112 g_loss : 1.988304
# batch 113 d_loss : 0.105311
# batch 113 g_loss : 2.088052
# batch 114 d_loss : 0.106591
# batch 114 g_loss : 2.093037
# batch 115 d_loss : 0.109660
# batch 115 g_loss : 2.187680
# batch 116 d_loss : 0.101834
# batch 116 g_loss : 2.194617
# batch 117 d_loss : 0.103895
# batch 117 g_loss : 2.253317
# batch 118 d_loss : 0.108814
# batch 118 g_loss : 2.306337
# batch 119 d_loss : 0.125275
# batch 119 g_loss : 2.255632
# batch 120 d_loss : 0.127369
# batch 120 g_loss : 2.241128
# batch 121 d_loss : 0.153533
# batch 121 g_loss : 2.353161
# batch 122 d_loss : 0.153877
# batch 122 g_loss : 2.284669
# batch 123 d_loss : 0.176756
# batch 123 g_loss : 2.359495
# batch 124 d_loss : 0.179863
# batch 124 g_loss : 2.370720
# batch 125 d_loss : 0.193412
# batch 125 g_loss : 2.471214
# batch 126 d_loss : 0.206405
# batch 126 g_loss : 2.506519
# batch 127 d_loss : 0.271797
# batch 127 g_loss : 2.495867
# batch 128 d_loss : 0.247352
# batch 128 g_loss : 2.490774
# batch 129 d_loss : 0.211445
# batch 129 g_loss : 2.364310
# batch 130 d_loss : 0.223174
# batch 130 g_loss : 2.362796
# batch 131 d_loss : 0.206659
# batch 131 g_loss : 2.322213
# batch 132 d_loss : 0.272743
# batch 132 g_loss : 2.204334
# batch 133 d_loss : 0.229805
# batch 133 g_loss : 1.999230
# batch 134 d_loss : 0.211927
# batch 134 g_loss : 1.910649
# batch 135 d_loss : 0.197017
# batch 135 g_loss : 1.662275
# batch 136 d_loss : 0.266040
# batch 136 g_loss : 1.516663
# batch 137 d_loss : 0.239500
# batch 137 g_loss : 1.319099
# batch 138 d_loss : 0.230446
# batch 138 g_loss : 1.198174
# batch 139 d_loss : 0.226306
# batch 139 g_loss : 1.104868
# batch 140 d_loss : 0.192975
# batch 140 g_loss : 1.036944
# batch 141 d_loss : 0.179359
# batch 141 g_loss : 1.027063
# batch 142 d_loss : 0.142532
# batch 142 g_loss : 0.986594
# batch 143 d_loss : 0.155152
# batch 143 g_loss : 0.957105
# batch 144 d_loss : 0.163440
# batch 144 g_loss : 0.998076
# batch 145 d_loss : 0.180123
# batch 145 g_loss : 0.860242
# batch 146 d_loss : 0.175393
# batch 146 g_loss : 0.807507
# batch 147 d_loss : 0.169321
# batch 147 g_loss : 0.657287
# batch 148 d_loss : 0.149330
# batch 148 g_loss : 0.605718
# batch 149 d_loss : 0.129569
# batch 149 g_loss : 0.568408
# batch 150 d_loss : 0.125815
# batch 150 g_loss : 0.555635
# batch 151 d_loss : 0.162484
# batch 151 g_loss : 0.545995
# batch 152 d_loss : 0.131122
# batch 152 g_loss : 0.644783
# batch 153 d_loss : 0.125346
# batch 153 g_loss : 0.629825
# batch 154 d_loss : 0.180664
# batch 154 g_loss : 0.585396
# batch 155 d_loss : 0.189573
# batch 155 g_loss : 0.498412
# batch 156 d_loss : 0.154764
# batch 156 g_loss : 0.523594
# batch 157 d_loss : 0.153008
# batch 157 g_loss : 0.483675
# batch 158 d_loss : 0.183047
# batch 158 g_loss : 0.457975
# batch 159 d_loss : 0.171699
# batch 159 g_loss : 0.433943
# batch 160 d_loss : 0.164250
# batch 160 g_loss : 0.446530
# batch 161 d_loss : 0.182376
# batch 161 g_loss : 0.420805
# batch 162 d_loss : 0.214643
# batch 162 g_loss : 0.441632
# batch 163 d_loss : 0.230950
# batch 163 g_loss : 0.537217
# batch 164 d_loss : 0.223583
# batch 164 g_loss : 0.509536
# batch 165 d_loss : 0.269553
# batch 165 g_loss : 0.440112
# batch 166 d_loss : 0.357561
# batch 166 g_loss : 0.498503
# batch 167 d_loss : 0.313025
# batch 167 g_loss : 0.376756
# batch 168 d_loss : 0.417151
# batch 168 g_loss : 0.382639
# batch 169 d_loss : 0.417820
# batch 169 g_loss : 0.349256
# batch 170 d_loss : 0.409716
# batch 170 g_loss : 0.367216
# batch 171 d_loss : 0.418689
# batch 171 g_loss : 0.308960
# batch 172 d_loss : 0.404117
# batch 172 g_loss : 0.389020
# batch 173 d_loss : 0.420479
# batch 173 g_loss : 0.406750
# batch 174 d_loss : 0.529608
# batch 174 g_loss : 0.473951
# batch 175 d_loss : 0.681559
# batch 175 g_loss : 0.410036
# batch 176 d_loss : 0.860127
# batch 176 g_loss : 0.296625
# batch 177 d_loss : 0.552310
# batch 177 g_loss : 0.407892
# batch 178 d_loss : 0.748144
# batch 178 g_loss : 0.296810
# batch 179 d_loss : 0.561379
# batch 179 g_loss : 0.336167
# batch 180 d_loss : 0.681231
# batch 180 g_loss : 0.356303
# batch 181 d_loss : 0.545548
# batch 181 g_loss : 0.466829
# batch 182 d_loss : 0.620122
# batch 182 g_loss : 0.563247
# batch 183 d_loss : 0.702243
# batch 183 g_loss : 0.627698
# batch 184 d_loss : 0.754505
# batch 184 g_loss : 0.579942
# batch 185 d_loss : 0.796181
# batch 185 g_loss : 0.534308
# batch 186 d_loss : 0.701551
# batch 186 g_loss : 0.623325
# batch 187 d_loss : 0.761332
# batch 187 g_loss : 0.548092
# batch 188 d_loss : 0.797323
# batch 188 g_loss : 0.559480
# batch 189 d_loss : 0.759769
# batch 189 g_loss : 0.496576
# batch 190 d_loss : 0.852084
# batch 190 g_loss : 0.537871
# batch 191 d_loss : 0.745858
# batch 191 g_loss : 0.620742
# batch 192 d_loss : 0.650633
# batch 192 g_loss : 0.688632
# batch 193 d_loss : 0.615676
# batch 193 g_loss : 0.787480
# batch 194 d_loss : 0.615027
# batch 194 g_loss : 0.967579
# batch 195 d_loss : 0.596589
# batch 195 g_loss : 1.088723
# batch 196 d_loss : 0.591767
# batch 196 g_loss : 1.088265
# batch 197 d_loss : 0.573205
# batch 197 g_loss : 1.123087
# batch 198 d_loss : 0.620573
# batch 198 g_loss : 1.061049
# batch 199 d_loss : 0.703598
# batch 199 g_loss : 0.882603
# batch 200 d_loss : 0.666013
# batch 200 g_loss : 0.906271
# batch 201 d_loss : 0.585996
# batch 201 g_loss : 0.884108
# batch 202 d_loss : 0.595492
# batch 202 g_loss : 0.863321
# batch 203 d_loss : 0.574147
# batch 203 g_loss : 1.002775
# batch 204 d_loss : 0.521622
# batch 204 g_loss : 1.108940
# batch 205 d_loss : 0.506485
# batch 205 g_loss : 1.184454
# batch 206 d_loss : 0.521583
# batch 206 g_loss : 1.230193
# batch 207 d_loss : 0.521717
# batch 207 g_loss : 1.267031
# batch 208 d_loss : 0.580176
# batch 208 g_loss : 1.172873
# batch 209 d_loss : 0.531999
# batch 209 g_loss : 1.169111
# batch 210 d_loss : 0.549766
# batch 210 g_loss : 1.144329
# batch 211 d_loss : 0.512543
# batch 211 g_loss : 1.136294
# batch 212 d_loss : 0.513424
# batch 212 g_loss : 1.147281
# batch 213 d_loss : 0.515459
# batch 213 g_loss : 1.178438
# batch 214 d_loss : 0.495456
# batch 214 g_loss : 1.186145
# batch 215 d_loss : 0.496163
# batch 215 g_loss : 1.231677
# batch 216 d_loss : 0.528295
# batch 216 g_loss : 1.254203
# batch 217 d_loss : 0.548482
# batch 217 g_loss : 1.252097
# batch 218 d_loss : 0.523679
# batch 218 g_loss : 1.222787
# batch 219 d_loss : 0.550124
# batch 219 g_loss : 1.187495
# batch 220 d_loss : 0.562858
# batch 220 g_loss : 1.154947
# batch 221 d_loss : 0.557986
# batch 221 g_loss : 1.128219
# batch 222 d_loss : 0.520663
# batch 222 g_loss : 1.151192
# batch 223 d_loss : 0.504020
# batch 223 g_loss : 1.188068
# batch 224 d_loss : 0.545992
# batch 224 g_loss : 1.099254
# batch 225 d_loss : 0.587564
# batch 225 g_loss : 1.101137
# batch 226 d_loss : 0.594047
# batch 226 g_loss : 1.038989
# batch 227 d_loss : 0.584965
# batch 227 g_loss : 0.968073
# batch 228 d_loss : 0.539009
# batch 228 g_loss : 0.982302
# batch 229 d_loss : 0.555945
# batch 229 g_loss : 0.962005
# batch 230 d_loss : 0.525863
# batch 230 g_loss : 1.020273
# batch 231 d_loss : 0.513295
# batch 231 g_loss : 0.993783
# batch 232 d_loss : 0.496226
# batch 232 g_loss : 0.958499
# batch 233 d_loss : 0.494535
# batch 233 g_loss : 0.899317
# batch 234 d_loss : 0.511956
# batch 234 g_loss : 0.880508
# batch 235 d_loss : 0.516231
# batch 235 g_loss : 0.847313
# batch 236 d_loss : 0.506688
# batch 236 g_loss : 0.860355
# batch 237 d_loss : 0.495077
# batch 237 g_loss : 0.828674
# batch 238 d_loss : 0.496697
# batch 238 g_loss : 0.882349
# batch 239 d_loss : 0.490310
# batch 239 g_loss : 0.862336
# batch 240 d_loss : 0.438521
# batch 240 g_loss : 0.775543
# batch 241 d_loss : 0.476363
# batch 241 g_loss : 0.852899
# batch 242 d_loss : 0.536185
# batch 242 g_loss : 0.801837
# batch 243 d_loss : 0.511771
# batch 243 g_loss : 0.724261
# batch 244 d_loss : 0.467677
# batch 244 g_loss : 0.786292
# batch 245 d_loss : 0.485549
# batch 245 g_loss : 0.771481
# batch 246 d_loss : 0.490000
# batch 246 g_loss : 0.776985
# batch 247 d_loss : 0.435525
# batch 247 g_loss : 0.778086
# batch 248 d_loss : 0.504503
# batch 248 g_loss : 0.744916
# batch 249 d_loss : 0.587649
# batch 249 g_loss : 0.624396
# batch 250 d_loss : 0.536504
# batch 250 g_loss : 0.631270
# batch 251 d_loss : 0.517288
# batch 251 g_loss : 0.701389
# batch 252 d_loss : 0.479090
# batch 252 g_loss : 0.739840
# batch 253 d_loss : 0.453302
# batch 253 g_loss : 0.717605
# batch 254 d_loss : 0.477707
# batch 254 g_loss : 0.804267
# batch 255 d_loss : 0.530782
# batch 255 g_loss : 0.778015
# batch 256 d_loss : 0.502340
# batch 256 g_loss : 0.767959
# batch 257 d_loss : 0.598939
# batch 257 g_loss : 0.705297
# batch 258 d_loss : 0.648102
# batch 258 g_loss : 0.570151
# batch 259 d_loss : 0.579669
# batch 259 g_loss : 0.565315
# batch 260 d_loss : 0.533802
# batch 260 g_loss : 0.636075
# batch 261 d_loss : 0.542257
# batch 261 g_loss : 0.715438
# batch 262 d_loss : 0.561894
# batch 262 g_loss : 0.806878
# batch 263 d_loss : 0.518591
# batch 263 g_loss : 0.743802
# batch 264 d_loss : 0.662603
# batch 264 g_loss : 0.713282
# batch 265 d_loss : 0.644458
# batch 265 g_loss : 0.622676
# batch 266 d_loss : 0.562474
# batch 266 g_loss : 0.642015
# batch 267 d_loss : 0.545095
# batch 267 g_loss : 0.727658
# batch 268 d_loss : 0.526828
# batch 268 g_loss : 0.879693
# batch 269 d_loss : 0.554307
# batch 269 g_loss : 0.873408
# batch 270 d_loss : 0.537403
# batch 270 g_loss : 0.891935
# batch 271 d_loss : 0.502184
# batch 271 g_loss : 0.880992
# batch 272 d_loss : 0.569383
# batch 272 g_loss : 0.825297
# batch 273 d_loss : 0.578050
# batch 273 g_loss : 0.831338
# batch 274 d_loss : 0.614015
# batch 274 g_loss : 0.818259
# batch 275 d_loss : 0.613975
# batch 275 g_loss : 0.778168
# batch 276 d_loss : 0.526562
# batch 276 g_loss : 0.894396
# batch 277 d_loss : 0.600605
# batch 277 g_loss : 0.895798
# batch 278 d_loss : 0.566261
# batch 278 g_loss : 0.904136
# batch 279 d_loss : 0.494865
# batch 279 g_loss : 0.983063
# batch 280 d_loss : 0.500814
# batch 280 g_loss : 1.068745
# batch 281 d_loss : 0.528317
# batch 281 g_loss : 1.176161
# batch 282 d_loss : 0.534162
# batch 282 g_loss : 1.120474
# batch 283 d_loss : 0.549501
# batch 283 g_loss : 1.038482
# batch 284 d_loss : 0.525528
# batch 284 g_loss : 0.995309
# batch 285 d_loss : 0.531882
# batch 285 g_loss : 1.016977
# batch 286 d_loss : 0.588489
# batch 286 g_loss : 0.956344
# batch 287 d_loss : 0.515907
# batch 287 g_loss : 1.058978
# batch 288 d_loss : 0.582035
# batch 288 g_loss : 1.019978
# batch 289 d_loss : 0.563762
# batch 289 g_loss : 1.082244
# batch 290 d_loss : 0.513174
# batch 290 g_loss : 1.153086
# batch 291 d_loss : 0.576253
# batch 291 g_loss : 1.134224
# batch 292 d_loss : 0.551480
# batch 292 g_loss : 1.111217
# batch 293 d_loss : 0.502193
# batch 293 g_loss : 1.222228
# batch 294 d_loss : 0.504554
# batch 294 g_loss : 1.182509
# batch 295 d_loss : 0.488590
# batch 295 g_loss : 1.153353
# batch 296 d_loss : 0.502670
# batch 296 g_loss : 1.123502
# batch 297 d_loss : 0.536739
# batch 297 g_loss : 1.052387
# batch 298 d_loss : 0.521856
# batch 298 g_loss : 1.078359
# batch 299 d_loss : 0.578287
# batch 299 g_loss : 1.092702
# batch 300 d_loss : 0.528515
# batch 300 g_loss : 1.054248
# batch 301 d_loss : 0.639738
# batch 301 g_loss : 1.044581
# batch 302 d_loss : 0.499375
# batch 302 g_loss : 1.167815
# batch 303 d_loss : 0.513184
# batch 303 g_loss : 1.218505
# batch 304 d_loss : 0.525924
# batch 304 g_loss : 1.258502
# batch 305 d_loss : 0.495649
# batch 305 g_loss : 1.205078
# batch 306 d_loss : 0.554290
# batch 306 g_loss : 1.136753
# batch 307 d_loss : 0.545467
# batch 307 g_loss : 1.079354
# batch 308 d_loss : 0.480227
# batch 308 g_loss : 1.179479
# batch 309 d_loss : 0.482091
# batch 309 g_loss : 1.219809
# batch 310 d_loss : 0.480468
# batch 310 g_loss : 1.290451
# batch 311 d_loss : 0.524418
# batch 311 g_loss : 1.219222
# batch 312 d_loss : 0.536523
# batch 312 g_loss : 1.115502
# batch 313 d_loss : 0.514045
# batch 313 g_loss : 1.137790
# batch 314 d_loss : 0.515315
# batch 314 g_loss : 1.129554
# batch 315 d_loss : 0.498115
# batch 315 g_loss : 1.160410
# batch 316 d_loss : 0.511369
# batch 316 g_loss : 1.127079
# batch 317 d_loss : 0.535271
# batch 317 g_loss : 1.113450
# batch 318 d_loss : 0.515347
# batch 318 g_loss : 1.149152
# batch 319 d_loss : 0.523043
# batch 319 g_loss : 1.184332
# batch 320 d_loss : 0.483825
# batch 320 g_loss : 1.236571
# batch 321 d_loss : 0.549923
# batch 321 g_loss : 1.113637
# batch 322 d_loss : 0.506238
# batch 322 g_loss : 1.102797
# batch 323 d_loss : 0.541427
# batch 323 g_loss : 1.106807
# batch 324 d_loss : 0.569399
# batch 324 g_loss : 1.071418
# batch 325 d_loss : 0.522241
# batch 325 g_loss : 1.067521
# batch 326 d_loss : 0.459277
# batch 326 g_loss : 1.102506
# batch 327 d_loss : 0.481101
# batch 327 g_loss : 1.079340
# batch 328 d_loss : 0.463932
# batch 328 g_loss : 1.163309
# batch 329 d_loss : 0.433651
# batch 329 g_loss : 1.205244
# batch 330 d_loss : 0.497699
# batch 330 g_loss : 1.145673
# batch 331 d_loss : 0.482473
# batch 331 g_loss : 1.104632
# batch 332 d_loss : 0.441355
# batch 332 g_loss : 1.065780
# batch 333 d_loss : 0.560822
# batch 333 g_loss : 1.010469
# batch 334 d_loss : 0.497274
# batch 334 g_loss : 1.005764
# batch 335 d_loss : 0.485842
# batch 335 g_loss : 0.971497
# batch 336 d_loss : 0.497235
# batch 336 g_loss : 0.976885
# batch 337 d_loss : 0.445831
# batch 337 g_loss : 1.081986
# batch 338 d_loss : 0.414716
# batch 338 g_loss : 1.150283
# batch 339 d_loss : 0.514374
# batch 339 g_loss : 1.132813
# batch 340 d_loss : 0.497009
# batch 340 g_loss : 0.974096
# batch 341 d_loss : 0.498476
# batch 341 g_loss : 0.998076
# batch 342 d_loss : 0.505574
# batch 342 g_loss : 1.005568
# batch 343 d_loss : 0.466035
# batch 343 g_loss : 1.143901
# batch 344 d_loss : 0.490626
# batch 344 g_loss : 1.155066
# batch 345 d_loss : 0.461166
# batch 345 g_loss : 1.090393
# batch 346 d_loss : 0.494434
# batch 346 g_loss : 1.103203
# batch 347 d_loss : 0.538218
# batch 347 g_loss : 1.022096
# batch 348 d_loss : 0.495613
# batch 348 g_loss : 0.984998
# batch 349 d_loss : 0.468275
# batch 349 g_loss : 1.025769
# batch 350 d_loss : 0.460348
# batch 350 g_loss : 1.082126
# batch 351 d_loss : 0.515419
# batch 351 g_loss : 1.089720
# batch 352 d_loss : 0.527521
# batch 352 g_loss : 1.039817
# batch 353 d_loss : 0.484927
# batch 353 g_loss : 1.011310
# batch 354 d_loss : 0.507614
# batch 354 g_loss : 1.021479
# batch 355 d_loss : 0.507049
# batch 355 g_loss : 1.096106
# batch 356 d_loss : 0.499919
# batch 356 g_loss : 1.013009
# batch 357 d_loss : 0.473103
# batch 357 g_loss : 1.027387
# batch 358 d_loss : 0.484570
# batch 358 g_loss : 1.086075
# batch 359 d_loss : 0.575465
# batch 359 g_loss : 0.932489
# batch 360 d_loss : 0.568912
# batch 360 g_loss : 0.900545
# batch 361 d_loss : 0.515060
# batch 361 g_loss : 0.984108
# batch 362 d_loss : 0.506931
# batch 362 g_loss : 1.143453
# batch 363 d_loss : 0.491026
# batch 363 g_loss : 1.263575
# batch 364 d_loss : 0.490148
# batch 364 g_loss : 1.215721
# batch 365 d_loss : 0.461598
# batch 365 g_loss : 1.178300
# batch 366 d_loss : 0.436874
# batch 366 g_loss : 1.185940
# batch 367 d_loss : 0.439269
# batch 367 g_loss : 1.238371
# batch 368 d_loss : 0.452434
# batch 368 g_loss : 1.257180
# batch 369 d_loss : 0.445885
# batch 369 g_loss : 1.277915
# batch 370 d_loss : 0.490229
# batch 370 g_loss : 1.229994
# batch 371 d_loss : 0.494158
# batch 371 g_loss : 1.149531
# batch 372 d_loss : 0.547753
# batch 372 g_loss : 1.210543
# batch 373 d_loss : 0.511135
# batch 373 g_loss : 1.191473
# batch 374 d_loss : 0.518036
# batch 374 g_loss : 1.088389
# batch 375 d_loss : 0.519104
# batch 375 g_loss : 1.048325
# batch 376 d_loss : 0.512653
# batch 376 g_loss : 0.972359
# batch 377 d_loss : 0.514859
# batch 377 g_loss : 1.082185
# batch 378 d_loss : 0.521121
# batch 378 g_loss : 1.124716
# batch 379 d_loss : 0.486137
# batch 379 g_loss : 1.153761
# batch 380 d_loss : 0.455740
# batch 380 g_loss : 1.215243
# batch 381 d_loss : 0.494865
# batch 381 g_loss : 1.255198
# batch 382 d_loss : 0.504881
# batch 382 g_loss : 1.278795
# batch 383 d_loss : 0.471467
# batch 383 g_loss : 1.139900
# batch 384 d_loss : 0.465969
# batch 384 g_loss : 1.163694
# batch 385 d_loss : 0.469102
# batch 385 g_loss : 1.137542
# batch 386 d_loss : 0.524975
# batch 386 g_loss : 1.141470
# batch 387 d_loss : 0.464981
# batch 387 g_loss : 1.227847
# batch 388 d_loss : 0.444373
# batch 388 g_loss : 1.328536
# batch 389 d_loss : 0.439243
# batch 389 g_loss : 1.402544
# batch 390 d_loss : 0.452404
# batch 390 g_loss : 1.325416
# batch 391 d_loss : 0.475369
# batch 391 g_loss : 1.273833
# batch 392 d_loss : 0.492866
# batch 392 g_loss : 1.190832
# batch 393 d_loss : 0.513513
# batch 393 g_loss : 1.092500
# batch 394 d_loss : 0.568629
# batch 394 g_loss : 1.096514
# batch 395 d_loss : 0.495425
# batch 395 g_loss : 1.259008
# batch 396 d_loss : 0.529215
# batch 396 g_loss : 1.305719
# batch 397 d_loss : 0.481606
# batch 397 g_loss : 1.225584
# batch 398 d_loss : 0.489166
# batch 398 g_loss : 1.122447
# batch 399 d_loss : 0.471581
# batch 399 g_loss : 1.199715
# batch 400 d_loss : 0.453567
# batch 400 g_loss : 1.243864
# batch 401 d_loss : 0.464057
# batch 401 g_loss : 1.241601
# batch 402 d_loss : 0.472242
# batch 402 g_loss : 1.252000
# batch 403 d_loss : 0.434035
# batch 403 g_loss : 1.301957
# batch 404 d_loss : 0.554187
# batch 404 g_loss : 1.173134
# batch 405 d_loss : 0.574264
# batch 405 g_loss : 1.090268
# batch 406 d_loss : 0.479981
# batch 406 g_loss : 1.143909
# batch 407 d_loss : 0.461245
# batch 407 g_loss : 1.145878
# batch 408 d_loss : 0.487432
# batch 408 g_loss : 1.179733
# batch 409 d_loss : 0.447567
# batch 409 g_loss : 1.182254
# batch 410 d_loss : 0.461790
# batch 410 g_loss : 1.193949
# batch 411 d_loss : 0.500380
# batch 411 g_loss : 1.181131
# batch 412 d_loss : 0.535006
# batch 412 g_loss : 1.150363
# batch 413 d_loss : 0.568273
# batch 413 g_loss : 0.940152
# batch 414 d_loss : 0.575540
# batch 414 g_loss : 0.985577
# batch 415 d_loss : 0.538270
# batch 415 g_loss : 1.090044
# batch 416 d_loss : 0.492913
# batch 416 g_loss : 1.084288
# batch 417 d_loss : 0.478500
# batch 417 g_loss : 1.082264
# batch 418 d_loss : 0.532081
# batch 418 g_loss : 1.067618
# batch 419 d_loss : 0.511172
# batch 419 g_loss : 1.156992
# batch 420 d_loss : 0.483730
# batch 420 g_loss : 1.247198
# batch 421 d_loss : 0.490467
# batch 421 g_loss : 1.183362
# batch 422 d_loss : 0.488721
# batch 422 g_loss : 1.191491
# batch 423 d_loss : 0.582289
# batch 423 g_loss : 1.122772
# batch 424 d_loss : 0.547273
# batch 424 g_loss : 1.027752
# batch 425 d_loss : 0.492157
# batch 425 g_loss : 1.071413
# batch 426 d_loss : 0.488852
# batch 426 g_loss : 1.162034
# batch 427 d_loss : 0.537021
# batch 427 g_loss : 1.116004
# batch 428 d_loss : 0.409609
# batch 428 g_loss : 1.286170
# batch 429 d_loss : 0.444722
# batch 429 g_loss : 1.276786
# batch 430 d_loss : 0.433586
# batch 430 g_loss : 1.252370
# batch 431 d_loss : 0.430918
# batch 431 g_loss : 1.264534
# batch 432 d_loss : 0.439425
# batch 432 g_loss : 1.204392
# batch 433 d_loss : 0.444708
# batch 433 g_loss : 1.239124
# batch 434 d_loss : 0.446804
# batch 434 g_loss : 1.109192
# batch 435 d_loss : 0.459315
# batch 435 g_loss : 1.149204
# batch 436 d_loss : 0.458729
# batch 436 g_loss : 1.173267
# batch 437 d_loss : 0.419837
# batch 437 g_loss : 1.183615
# batch 438 d_loss : 0.458655
# batch 438 g_loss : 1.179281
# batch 439 d_loss : 0.436894
# batch 439 g_loss : 1.182129
# batch 440 d_loss : 0.517326
# batch 440 g_loss : 1.102427
# batch 441 d_loss : 0.525900
# batch 441 g_loss : 0.969746
# batch 442 d_loss : 0.503996
# batch 442 g_loss : 1.052453
# batch 443 d_loss : 0.507845
# batch 443 g_loss : 1.110241
# batch 444 d_loss : 0.471121
# batch 444 g_loss : 1.237936
# batch 445 d_loss : 0.448025
# batch 445 g_loss : 1.294829
# batch 446 d_loss : 0.403241
# batch 446 g_loss : 1.315851
# batch 447 d_loss : 0.459509
# batch 447 g_loss : 1.166975
# batch 448 d_loss : 0.492407
# batch 448 g_loss : 1.139282
# batch 449 d_loss : 0.463798
# batch 449 g_loss : 1.182460
# batch 450 d_loss : 0.487443
# batch 450 g_loss : 1.211575
# batch 451 d_loss : 0.449632
# batch 451 g_loss : 1.166751
# batch 452 d_loss : 0.462880
# batch 452 g_loss : 1.247728
# batch 453 d_loss : 0.463775
# batch 453 g_loss : 1.301055
# batch 454 d_loss : 0.491425
# batch 454 g_loss : 1.169691
# batch 455 d_loss : 0.496325
# batch 455 g_loss : 1.190674
# batch 456 d_loss : 0.456734
# batch 456 g_loss : 1.239864
# batch 457 d_loss : 0.488661
# batch 457 g_loss : 1.135152
# batch 458 d_loss : 0.461927
# batch 458 g_loss : 1.228753
# batch 459 d_loss : 0.539697
# batch 459 g_loss : 0.980903
# batch 460 d_loss : 0.534153
# batch 460 g_loss : 1.120124
# batch 461 d_loss : 0.460897
# batch 461 g_loss : 1.250980
# batch 462 d_loss : 0.437142
# batch 462 g_loss : 1.265353
# batch 463 d_loss : 0.470723
# batch 463 g_loss : 1.205108
# batch 464 d_loss : 0.510389
# batch 464 g_loss : 1.216501
# batch 465 d_loss : 0.458361
# batch 465 g_loss : 1.233446
# batch 466 d_loss : 0.458650
# batch 466 g_loss : 1.283821
# batch 467 d_loss : 0.449806
# batch 467 g_loss : 1.228834
# batch 468 d_loss : 0.417552
# batch 468 g_loss : 1.251190
# batch 469 d_loss : 0.491925
# batch 469 g_loss : 1.071023
# batch 470 d_loss : 0.521302
# batch 470 g_loss : 1.147297
# batch 471 d_loss : 0.473259
# batch 471 g_loss : 1.238178
# batch 472 d_loss : 0.501940
# batch 472 g_loss : 1.055281
# batch 473 d_loss : 0.477823
# batch 473 g_loss : 1.195704
# batch 474 d_loss : 0.540020
# batch 474 g_loss : 1.169090
# batch 475 d_loss : 0.519210
# batch 475 g_loss : 1.253854
# batch 476 d_loss : 0.544206
# batch 476 g_loss : 1.104456
# batch 477 d_loss : 0.487955
# batch 477 g_loss : 1.233084
# batch 478 d_loss : 0.450936
# batch 478 g_loss : 1.260054
# batch 479 d_loss : 0.500430
# batch 479 g_loss : 1.103145
# batch 480 d_loss : 0.468140
# batch 480 g_loss : 1.169778
# batch 481 d_loss : 0.481766
# batch 481 g_loss : 1.193681
# batch 482 d_loss : 0.533654
# batch 482 g_loss : 1.196484
# batch 483 d_loss : 0.503373
# batch 483 g_loss : 1.073976
# batch 484 d_loss : 0.527110
# batch 484 g_loss : 1.249043
# batch 485 d_loss : 0.490562
# batch 485 g_loss : 1.241175
# batch 486 d_loss : 0.475586
# batch 486 g_loss : 1.229517
# batch 487 d_loss : 0.435222
# batch 487 g_loss : 1.295260
# batch 488 d_loss : 0.472078
# batch 488 g_loss : 1.180641
# batch 489 d_loss : 0.488846
# batch 489 g_loss : 1.061946
# batch 490 d_loss : 0.506169
# batch 490 g_loss : 1.076833
# batch 491 d_loss : 0.630010
# batch 491 g_loss : 0.876746
# batch 492 d_loss : 0.477260
# batch 492 g_loss : 1.163588
# batch 493 d_loss : 0.422241
# batch 493 g_loss : 1.264418
# batch 494 d_loss : 0.554949
# batch 494 g_loss : 1.366195
# batch 495 d_loss : 0.636337
# batch 495 g_loss : 0.970941
# batch 496 d_loss : 0.471135
# batch 496 g_loss : 1.171812
# batch 497 d_loss : 0.424038
# batch 497 g_loss : 1.403010
# batch 498 d_loss : 0.499271
# batch 498 g_loss : 1.186604
# batch 499 d_loss : 0.457879
# batch 499 g_loss : 1.197765
# batch 500 d_loss : 0.431093
# batch 500 g_loss : 1.207711
# batch 501 d_loss : 0.431594
# batch 501 g_loss : 1.415954
# batch 502 d_loss : 0.388995
# batch 502 g_loss : 1.403720
# batch 503 d_loss : 0.475471
# batch 503 g_loss : 1.103569
# batch 504 d_loss : 0.460713
# batch 504 g_loss : 1.115800
# batch 505 d_loss : 0.458382
# batch 505 g_loss : 1.282903
# batch 506 d_loss : 0.431572
# batch 506 g_loss : 1.365331
# batch 507 d_loss : 0.416760
# batch 507 g_loss : 1.459470
# batch 508 d_loss : 0.409104
# batch 508 g_loss : 1.400870
# batch 509 d_loss : 0.418200
# batch 509 g_loss : 1.392835
# batch 510 d_loss : 0.356748
# batch 510 g_loss : 1.469793
# batch 511 d_loss : 0.546761
# batch 511 g_loss : 1.215421
# batch 512 d_loss : 0.532455
# batch 512 g_loss : 1.136675
# batch 513 d_loss : 0.472631
# batch 513 g_loss : 1.114545
# batch 514 d_loss : 0.442809
# batch 514 g_loss : 1.396262
# batch 515 d_loss : 0.428805
# batch 515 g_loss : 1.265741
# batch 516 d_loss : 0.416988
# batch 516 g_loss : 1.235520
# batch 517 d_loss : 0.484113
# batch 517 g_loss : 1.088937
# batch 518 d_loss : 0.393932
# batch 518 g_loss : 1.274084
# batch 519 d_loss : 0.404738
# batch 519 g_loss : 1.287222
# batch 520 d_loss : 0.496303
# batch 520 g_loss : 1.076679
# batch 521 d_loss : 0.519893
# batch 521 g_loss : 0.961862
# batch 522 d_loss : 0.441738
# batch 522 g_loss : 1.361843
# batch 523 d_loss : 0.403792
# batch 523 g_loss : 1.467740
# batch 524 d_loss : 0.418919
# batch 524 g_loss : 1.291944
# batch 525 d_loss : 0.377518
# batch 525 g_loss : 1.384564
# batch 526 d_loss : 0.447265
# batch 526 g_loss : 1.239124
# batch 527 d_loss : 0.424992
# batch 527 g_loss : 1.248972
# batch 528 d_loss : 0.411109
# batch 528 g_loss : 1.366942
# batch 529 d_loss : 0.401921
# batch 529 g_loss : 1.363739
# batch 530 d_loss : 0.387960
# batch 530 g_loss : 1.316885
# batch 531 d_loss : 0.390243
# batch 531 g_loss : 1.357810
# batch 532 d_loss : 0.400135
# batch 532 g_loss : 1.328747
# batch 533 d_loss : 0.441641
# batch 533 g_loss : 1.302226
# batch 534 d_loss : 0.403314
# batch 534 g_loss : 1.187991
# batch 535 d_loss : 0.424550
# batch 535 g_loss : 1.323040
# batch 536 d_loss : 0.414101
# batch 536 g_loss : 1.329460
# batch 537 d_loss : 0.370780
# batch 537 g_loss : 1.294024
# batch 538 d_loss : 0.355112
# batch 538 g_loss : 1.386529
# batch 539 d_loss : 0.437978
# batch 539 g_loss : 1.271774
# batch 540 d_loss : 0.420333
# batch 540 g_loss : 1.358172
# batch 541 d_loss : 0.366329
# batch 541 g_loss : 1.350394
# batch 542 d_loss : 0.360348
# batch 542 g_loss : 1.228916
# batch 543 d_loss : 0.426156
# batch 543 g_loss : 1.297478
# batch 544 d_loss : 0.411909
# batch 544 g_loss : 1.356552
# batch 545 d_loss : 0.395410
# batch 545 g_loss : 1.502195
# batch 546 d_loss : 0.374535
# batch 546 g_loss : 1.407217
# batch 547 d_loss : 0.362110
# batch 547 g_loss : 1.328079
# batch 548 d_loss : 0.436558
# batch 548 g_loss : 1.160305
# batch 549 d_loss : 0.475918
# batch 549 g_loss : 1.287768
# batch 550 d_loss : 0.402271
# batch 550 g_loss : 1.342776
# batch 551 d_loss : 0.381484
# batch 551 g_loss : 1.452003
# batch 552 d_loss : 0.365742
# batch 552 g_loss : 1.316482
# batch 553 d_loss : 0.368208
# batch 553 g_loss : 1.385896
# batch 554 d_loss : 0.352374
# batch 554 g_loss : 1.382579
# batch 555 d_loss : 0.436132
# batch 555 g_loss : 1.297347
# batch 556 d_loss : 0.417785
# batch 556 g_loss : 1.416522
# batch 557 d_loss : 0.363976
# batch 557 g_loss : 1.435951
# batch 558 d_loss : 0.311864
# batch 558 g_loss : 1.485849
# batch 559 d_loss : 0.345469
# batch 559 g_loss : 1.461421
# batch 560 d_loss : 0.432136
# batch 560 g_loss : 1.259954
# batch 561 d_loss : 0.392983
# batch 561 g_loss : 1.361716
# batch 562 d_loss : 0.436934
# batch 562 g_loss : 1.228259
# batch 563 d_loss : 0.395360
# batch 563 g_loss : 1.361720
# batch 564 d_loss : 0.421479
# batch 564 g_loss : 1.183517
# batch 565 d_loss : 0.460671
# batch 565 g_loss : 1.117179
# batch 566 d_loss : 0.417247
# batch 566 g_loss : 1.214176
# batch 567 d_loss : 0.385207
# batch 567 g_loss : 1.529593
# batch 568 d_loss : 0.387730
# batch 568 g_loss : 1.528474
# batch 569 d_loss : 0.379049
# batch 569 g_loss : 1.252393
# batch 570 d_loss : 0.412786
# batch 570 g_loss : 1.156449
# batch 571 d_loss : 0.369332
# batch 571 g_loss : 1.260562
# batch 572 d_loss : 0.339708
# batch 572 g_loss : 1.562946
# batch 573 d_loss : 0.353453
# batch 573 g_loss : 1.323936
# batch 574 d_loss : 0.345074
# batch 574 g_loss : 1.307612
# batch 575 d_loss : 0.360920
# batch 575 g_loss : 1.379293
# batch 576 d_loss : 0.339095
# batch 576 g_loss : 1.437780
# batch 577 d_loss : 0.333174
# batch 577 g_loss : 1.358600
# batch 578 d_loss : 0.318024
# batch 578 g_loss : 1.490163
# batch 579 d_loss : 0.396441
# batch 579 g_loss : 1.261708
# batch 580 d_loss : 0.348545
# batch 580 g_loss : 1.494184
# batch 581 d_loss : 0.372647
# batch 581 g_loss : 1.095047
# batch 582 d_loss : 0.335037
# batch 582 g_loss : 1.832163
# batch 583 d_loss : 0.429062
# batch 583 g_loss : 1.140839
# batch 584 d_loss : 0.392869
# batch 584 g_loss : 1.765324
# batch 585 d_loss : 0.379501
# batch 585 g_loss : 1.083825
# batch 586 d_loss : 0.320755
# batch 586 g_loss : 2.060072
# batch 587 d_loss : 0.346364
# batch 587 g_loss : 1.094672
# batch 588 d_loss : 0.379510
# batch 588 g_loss : 1.666908
# batch 589 d_loss : 0.290796
# batch 589 g_loss : 1.490503
# batch 590 d_loss : 0.283889
# batch 590 g_loss : 1.877241
# batch 591 d_loss : 0.280987
# batch 591 g_loss : 1.614961
# batch 592 d_loss : 0.276900
# batch 592 g_loss : 1.585513
# batch 593 d_loss : 0.475998
# batch 593 g_loss : 1.520815
# batch 594 d_loss : 0.513533
# batch 594 g_loss : 1.393025
# batch 595 d_loss : 0.276093
# batch 595 g_loss : 1.977516
# batch 596 d_loss : 0.345939
# batch 596 g_loss : 1.322211
# batch 597 d_loss : 0.336599
# batch 597 g_loss : 1.679759
# batch 598 d_loss : 0.307973
# batch 598 g_loss : 1.957016
# batch 599 d_loss : 0.573125
# batch 599 g_loss : 0.391447
# Epoch is 1
# Number of batches 600
# batch 0 d_loss : 0.689814
# batch 0 g_loss : 2.376271
# batch 1 d_loss : 0.520460
# batch 1 g_loss : 1.205593
# batch 2 d_loss : 0.369944
# batch 2 g_loss : 1.441493
# batch 3 d_loss : 0.327555
# batch 3 g_loss : 1.618941
# batch 4 d_loss : 0.429742
# batch 4 g_loss : 1.350528
# batch 5 d_loss : 0.393059
# batch 5 g_loss : 1.459416
# batch 6 d_loss : 0.377145
# batch 6 g_loss : 1.448477
# batch 7 d_loss : 0.384017
# batch 7 g_loss : 1.635438
# batch 8 d_loss : 0.340479
# batch 8 g_loss : 1.569234
# batch 9 d_loss : 0.326948
# batch 9 g_loss : 1.491583
# batch 10 d_loss : 0.374207
# batch 10 g_loss : 1.164511
# batch 11 d_loss : 0.420317
# batch 11 g_loss : 1.486666
# batch 12 d_loss : 0.404794
# batch 12 g_loss : 1.578453
# batch 13 d_loss : 0.388701
# batch 13 g_loss : 1.530706
# batch 14 d_loss : 0.381130
# batch 14 g_loss : 1.520468
# batch 15 d_loss : 0.356212
# batch 15 g_loss : 1.470104
# batch 16 d_loss : 0.333710
# batch 16 g_loss : 1.493495
# batch 17 d_loss : 0.314246
# batch 17 g_loss : 1.916355
# batch 18 d_loss : 0.420644
# batch 18 g_loss : 1.013096
# batch 19 d_loss : 0.434902
# batch 19 g_loss : 1.919933
# batch 20 d_loss : 0.391316
# batch 20 g_loss : 1.328375
# batch 21 d_loss : 0.332834
# batch 21 g_loss : 1.857881
# batch 22 d_loss : 0.346201
# batch 22 g_loss : 1.338340
# batch 23 d_loss : 0.329785
# batch 23 g_loss : 1.420571
# batch 24 d_loss : 0.302910
# batch 24 g_loss : 1.670342
# batch 25 d_loss : 0.302425
# batch 25 g_loss : 1.667969
# batch 26 d_loss : 0.324987
# batch 26 g_loss : 1.628579
# batch 27 d_loss : 0.430024
# batch 27 g_loss : 0.872720
# batch 28 d_loss : 0.444598
# batch 28 g_loss : 1.734705
# batch 29 d_loss : 0.286417
# batch 29 g_loss : 1.556055
# batch 30 d_loss : 0.279225
# batch 30 g_loss : 1.620788
# batch 31 d_loss : 0.279830
# batch 31 g_loss : 1.673403
# batch 32 d_loss : 0.308688
# batch 32 g_loss : 1.461895
# batch 33 d_loss : 0.317362
# batch 33 g_loss : 1.493958
# batch 34 d_loss : 0.274334
# batch 34 g_loss : 1.666305
# batch 35 d_loss : 0.391535
# batch 35 g_loss : 1.331332
# batch 36 d_loss : 0.387563
# batch 36 g_loss : 1.640436
# batch 37 d_loss : 0.323797
# batch 37 g_loss : 1.222389
# batch 38 d_loss : 0.312341
# batch 38 g_loss : 2.065167
# batch 39 d_loss : 0.295158
# batch 39 g_loss : 1.449297
# batch 40 d_loss : 0.347099
# batch 40 g_loss : 1.561869
# batch 41 d_loss : 0.361982
# batch 41 g_loss : 1.281686
# batch 42 d_loss : 0.320692
# batch 42 g_loss : 1.963927
# batch 43 d_loss : 0.305531
# batch 43 g_loss : 1.186220
# batch 44 d_loss : 0.369098
# batch 44 g_loss : 2.219392
# batch 45 d_loss : 0.424590
# batch 45 g_loss : 0.729069
# batch 46 d_loss : 0.489324
# batch 46 g_loss : 2.867869
# batch 47 d_loss : 0.664100
# batch 47 g_loss : 0.466057
# batch 48 d_loss : 0.693270
# batch 48 g_loss : 3.590254
# batch 49 d_loss : 0.739165
# batch 49 g_loss : 0.531932
# batch 50 d_loss : 0.606574
# batch 50 g_loss : 3.340480
# batch 51 d_loss : 0.592276
# batch 51 g_loss : 0.941014
# batch 52 d_loss : 0.403065
# batch 52 g_loss : 2.386133
# batch 53 d_loss : 0.375292
# batch 53 g_loss : 1.107691
# batch 54 d_loss : 0.403063
# batch 54 g_loss : 1.846384
# batch 55 d_loss : 0.315641
# batch 55 g_loss : 1.465909
# batch 56 d_loss : 0.343824
# batch 56 g_loss : 1.328193
# batch 57 d_loss : 0.383162
# batch 57 g_loss : 1.702161
# batch 58 d_loss : 0.354164
# batch 58 g_loss : 1.255149
# batch 59 d_loss : 0.330290
# batch 59 g_loss : 1.705895
# batch 60 d_loss : 0.416290
# batch 60 g_loss : 1.385021
# batch 61 d_loss : 0.389973
# batch 61 g_loss : 1.606356
# batch 62 d_loss : 0.328297
# batch 62 g_loss : 1.442960
# batch 63 d_loss : 0.341682
# batch 63 g_loss : 1.574469
# batch 64 d_loss : 0.373227
# batch 64 g_loss : 1.262959
# batch 65 d_loss : 0.317639
# batch 65 g_loss : 1.971288
# batch 66 d_loss : 0.342766
# batch 66 g_loss : 1.046599
# batch 67 d_loss : 0.393031
# batch 67 g_loss : 1.764692
# batch 68 d_loss : 0.446120
# batch 68 g_loss : 0.767943
# batch 69 d_loss : 0.460535
# batch 69 g_loss : 2.660357
# batch 70 d_loss : 0.495917
# batch 70 g_loss : 0.877340
# batch 71 d_loss : 0.413581
# batch 71 g_loss : 2.266013
# batch 72 d_loss : 0.627606
# batch 72 g_loss : 0.317212
# batch 73 d_loss : 0.785841
# batch 73 g_loss : 2.731987
# batch 74 d_loss : 0.460825
# batch 74 g_loss : 0.843035
# batch 75 d_loss : 0.408307
# batch 75 g_loss : 2.813915
# batch 76 d_loss : 0.587919
# batch 76 g_loss : 0.566926
# batch 77 d_loss : 0.610675
# batch 77 g_loss : 3.247303
# batch 78 d_loss : 0.795119
# batch 78 g_loss : 0.747275
# batch 79 d_loss : 0.568431
# batch 79 g_loss : 2.078925
# batch 80 d_loss : 0.519491
# batch 80 g_loss : 0.716804
# batch 81 d_loss : 0.430142
# batch 81 g_loss : 2.536772
# batch 82 d_loss : 0.467078
# batch 82 g_loss : 0.945450
# batch 83 d_loss : 0.390964
# batch 83 g_loss : 1.737831
# batch 84 d_loss : 0.451713
# batch 84 g_loss : 1.208840
# batch 85 d_loss : 0.463800
# batch 85 g_loss : 1.459657
# batch 86 d_loss : 0.403968
# batch 86 g_loss : 1.701541
# batch 87 d_loss : 0.382457
# batch 87 g_loss : 1.775862
# batch 88 d_loss : 0.413673
# batch 88 g_loss : 1.226452
# batch 89 d_loss : 0.388907
# batch 89 g_loss : 1.864524
# batch 90 d_loss : 0.412295
# batch 90 g_loss : 1.326051
# batch 91 d_loss : 0.378571
# batch 91 g_loss : 1.167528
# batch 92 d_loss : 0.501419
# batch 92 g_loss : 1.234274
# batch 93 d_loss : 0.417991
# batch 93 g_loss : 1.592813
# batch 94 d_loss : 0.405393
# batch 94 g_loss : 1.353076
# batch 95 d_loss : 0.394141
# batch 95 g_loss : 1.187039
# batch 96 d_loss : 0.402559
# batch 96 g_loss : 1.356511
# batch 97 d_loss : 0.331903
# batch 97 g_loss : 1.633057
# batch 98 d_loss : 0.366283
# batch 98 g_loss : 1.303958
# batch 99 d_loss : 0.356462
# batch 99 g_loss : 1.542439
# batch 100 d_loss : 0.340374
# batch 100 g_loss : 1.531700
# batch 101 d_loss : 0.325662
# batch 101 g_loss : 1.339388
# batch 102 d_loss : 0.514860
# batch 102 g_loss : 1.685547
# batch 103 d_loss : 0.375237
# batch 103 g_loss : 1.325600
# batch 104 d_loss : 0.368502
# batch 104 g_loss : 1.378651
# batch 105 d_loss : 0.362057
# batch 105 g_loss : 1.594796
# batch 106 d_loss : 0.365076
# batch 106 g_loss : 1.190085
# batch 107 d_loss : 0.357900
# batch 107 g_loss : 1.574148
# batch 108 d_loss : 0.320815
# batch 108 g_loss : 1.534080
# batch 109 d_loss : 0.396697
# batch 109 g_loss : 1.371883
# batch 110 d_loss : 0.403469
# batch 110 g_loss : 1.581295
# batch 111 d_loss : 0.351290
# batch 111 g_loss : 1.483219
# batch 112 d_loss : 0.359021
# batch 112 g_loss : 1.192635
# batch 113 d_loss : 0.378703
# batch 113 g_loss : 1.936946
# batch 114 d_loss : 0.418832
# batch 114 g_loss : 0.993923
# batch 115 d_loss : 0.414719
# batch 115 g_loss : 1.669299
# batch 116 d_loss : 0.459464
# batch 116 g_loss : 1.163703
# batch 117 d_loss : 0.444330
# batch 117 g_loss : 1.959792
# batch 118 d_loss : 0.390489
# batch 118 g_loss : 1.040844
# batch 119 d_loss : 0.387123
# batch 119 g_loss : 1.651619
# batch 120 d_loss : 0.414828
# batch 120 g_loss : 1.038020
# batch 121 d_loss : 0.422135
# batch 121 g_loss : 1.909369
# batch 122 d_loss : 0.384269
# batch 122 g_loss : 1.323330
# batch 123 d_loss : 0.458186
# batch 123 g_loss : 1.185334
# batch 124 d_loss : 0.425031
# batch 124 g_loss : 1.646098
# batch 125 d_loss : 0.388248
# batch 125 g_loss : 1.465148
# batch 126 d_loss : 0.375627
# batch 126 g_loss : 1.597164
# batch 127 d_loss : 0.418919
# batch 127 g_loss : 1.060687
# batch 128 d_loss : 0.438899
# batch 128 g_loss : 1.936404
# batch 129 d_loss : 0.573661
# batch 129 g_loss : 0.800438
# batch 130 d_loss : 0.543392
# batch 130 g_loss : 2.128438
# batch 131 d_loss : 0.512462
# batch 131 g_loss : 0.923229
# batch 132 d_loss : 0.433320
# batch 132 g_loss : 1.530854
# batch 133 d_loss : 0.412313
# batch 133 g_loss : 1.110916
# batch 134 d_loss : 0.387709
# batch 134 g_loss : 2.147883
# batch 135 d_loss : 0.446467
# batch 135 g_loss : 1.058659
# batch 136 d_loss : 0.509787
# batch 136 g_loss : 0.730489
# batch 137 d_loss : 0.502772
# batch 137 g_loss : 1.844442
# batch 138 d_loss : 0.444394
# batch 138 g_loss : 0.893001
# batch 139 d_loss : 0.503414
# batch 139 g_loss : 1.480090
# batch 140 d_loss : 0.533471
# batch 140 g_loss : 0.962747
# batch 141 d_loss : 0.541756
# batch 141 g_loss : 1.281505
# batch 142 d_loss : 0.470157
# batch 142 g_loss : 1.036845
# batch 143 d_loss : 0.502395
# batch 143 g_loss : 1.260810
# batch 144 d_loss : 0.426020
# batch 144 g_loss : 1.306066
# batch 145 d_loss : 0.472295
# batch 145 g_loss : 0.912946
# batch 146 d_loss : 0.496032
# batch 146 g_loss : 1.427101
# batch 147 d_loss : 0.562025
# batch 147 g_loss : 0.654759
# batch 148 d_loss : 0.607486
# batch 148 g_loss : 1.806637
# batch 149 d_loss : 0.463275
# batch 149 g_loss : 0.873682
# batch 150 d_loss : 0.442785
# batch 150 g_loss : 1.814968
# batch 151 d_loss : 0.502017
# batch 151 g_loss : 0.563785
# batch 152 d_loss : 0.566820
# batch 152 g_loss : 2.557184
# batch 153 d_loss : 0.617843
# batch 153 g_loss : 0.457243
# batch 154 d_loss : 0.631298
# batch 154 g_loss : 2.204889
# batch 155 d_loss : 0.631034
# batch 155 g_loss : 0.491903
# batch 156 d_loss : 0.706760
# batch 156 g_loss : 2.846367
# batch 157 d_loss : 0.748628
# batch 157 g_loss : 0.520830
# batch 158 d_loss : 0.722907
# batch 158 g_loss : 2.537662
# batch 159 d_loss : 0.879744
# batch 159 g_loss : 0.378568
# batch 160 d_loss : 0.776482
# batch 160 g_loss : 2.195699
# batch 161 d_loss : 0.602110
# batch 161 g_loss : 0.886708
# batch 162 d_loss : 0.502313
# batch 162 g_loss : 1.498736
# batch 163 d_loss : 0.399733
# batch 163 g_loss : 1.307346
# batch 164 d_loss : 0.348308
# batch 164 g_loss : 1.613673
# batch 165 d_loss : 0.330858
# batch 165 g_loss : 1.299377
# batch 166 d_loss : 0.394383
# batch 166 g_loss : 1.328030
# batch 167 d_loss : 0.395262
# batch 167 g_loss : 1.367269
# batch 168 d_loss : 0.464040
# batch 168 g_loss : 1.039344
# batch 169 d_loss : 0.480536
# batch 169 g_loss : 1.387733
# batch 170 d_loss : 0.433639
# batch 170 g_loss : 1.150869
# batch 171 d_loss : 0.454062
# batch 171 g_loss : 1.438977
# batch 172 d_loss : 0.432921
# batch 172 g_loss : 1.334019
# batch 173 d_loss : 0.410343
# batch 173 g_loss : 1.227080
# batch 174 d_loss : 0.438699
# batch 174 g_loss : 1.362536
# batch 175 d_loss : 0.498084
# batch 175 g_loss : 0.881191
# batch 176 d_loss : 0.527278
# batch 176 g_loss : 1.095686
# batch 177 d_loss : 0.396531
# batch 177 g_loss : 1.368666
# batch 178 d_loss : 0.417907
# batch 178 g_loss : 1.297243
# batch 179 d_loss : 0.417514
# batch 179 g_loss : 1.309058
# batch 180 d_loss : 0.373714
# batch 180 g_loss : 1.405568
# batch 181 d_loss : 0.430588
# batch 181 g_loss : 1.467005
# batch 182 d_loss : 0.493377
# batch 182 g_loss : 1.152945
# batch 183 d_loss : 0.437851
# batch 183 g_loss : 1.512798
# batch 184 d_loss : 0.400260
# batch 184 g_loss : 1.314872
# batch 185 d_loss : 0.462110
# batch 185 g_loss : 1.370448
# batch 186 d_loss : 0.380906
# batch 186 g_loss : 1.507067
# batch 187 d_loss : 0.351696
# batch 187 g_loss : 1.421620
# batch 188 d_loss : 0.454197
# batch 188 g_loss : 1.324107
# batch 189 d_loss : 0.400398
# batch 189 g_loss : 1.339474
# batch 190 d_loss : 0.420459
# batch 190 g_loss : 1.301467
# batch 191 d_loss : 0.412747
# batch 191 g_loss : 1.474136
# batch 192 d_loss : 0.678902
# batch 192 g_loss : 1.006067
# batch 193 d_loss : 0.625121
# batch 193 g_loss : 1.243859
# batch 194 d_loss : 0.683187
# batch 194 g_loss : 1.008156
# batch 195 d_loss : 0.657303
# batch 195 g_loss : 1.404606
# batch 196 d_loss : 0.549550
# batch 196 g_loss : 1.217896
# batch 197 d_loss : 0.430343
# batch 197 g_loss : 1.466971
# batch 198 d_loss : 0.469017
# batch 198 g_loss : 1.147758
# batch 199 d_loss : 0.560927
# batch 199 g_loss : 1.101504
# batch 200 d_loss : 0.563566
# batch 200 g_loss : 1.317342
# batch 201 d_loss : 0.544843
# batch 201 g_loss : 1.342188
# batch 202 d_loss : 0.584414
# batch 202 g_loss : 1.178519
# batch 203 d_loss : 0.553666
# batch 203 g_loss : 1.171268
# batch 204 d_loss : 0.506961
# batch 204 g_loss : 1.363367
# batch 205 d_loss : 0.524824
# batch 205 g_loss : 1.209243
# batch 206 d_loss : 0.546957
# batch 206 g_loss : 1.216645
# batch 207 d_loss : 0.494330
# batch 207 g_loss : 1.036466
# batch 208 d_loss : 0.523013
# batch 208 g_loss : 0.912357
# batch 209 d_loss : 0.547966
# batch 209 g_loss : 1.138918
# batch 210 d_loss : 0.399648
# batch 210 g_loss : 1.341418
# batch 211 d_loss : 0.371403
# batch 211 g_loss : 1.605003
# batch 212 d_loss : 0.330756
# batch 212 g_loss : 1.663492
# batch 213 d_loss : 0.341758
# batch 213 g_loss : 1.653167
# batch 214 d_loss : 0.447094
# batch 214 g_loss : 1.690109
# batch 215 d_loss : 0.356766
# batch 215 g_loss : 1.949043
# batch 216 d_loss : 0.301286
# batch 216 g_loss : 2.031272
# batch 217 d_loss : 0.465685
# batch 217 g_loss : 1.785343
# batch 218 d_loss : 0.678405
# batch 218 g_loss : 1.305448
# batch 219 d_loss : 0.681788
# batch 219 g_loss : 1.377635
# batch 220 d_loss : 0.476443
# batch 220 g_loss : 1.526212
# batch 221 d_loss : 0.416928
# batch 221 g_loss : 1.749697
# batch 222 d_loss : 0.522087
# batch 222 g_loss : 1.064371
# batch 223 d_loss : 0.490856
# batch 223 g_loss : 1.598795
# batch 224 d_loss : 0.594143
# batch 224 g_loss : 0.650810
# batch 225 d_loss : 0.655421
# batch 225 g_loss : 1.841035
# batch 226 d_loss : 0.620591
# batch 226 g_loss : 1.123045
# batch 227 d_loss : 0.475366
# batch 227 g_loss : 1.826447
# batch 228 d_loss : 0.443580
# batch 228 g_loss : 1.345540
# batch 229 d_loss : 0.458353
# batch 229 g_loss : 1.617359
# batch 230 d_loss : 0.420800
# batch 230 g_loss : 1.828914
# batch 231 d_loss : 0.430841
# batch 231 g_loss : 1.845708
# batch 232 d_loss : 0.483748
# batch 232 g_loss : 1.346794
# batch 233 d_loss : 0.555479
# batch 233 g_loss : 1.414619
# batch 234 d_loss : 0.610328
# batch 234 g_loss : 1.350569
# batch 235 d_loss : 0.610016
# batch 235 g_loss : 1.024045
# batch 236 d_loss : 0.603107
# batch 236 g_loss : 1.117852
# batch 237 d_loss : 0.646495
# batch 237 g_loss : 1.027537
# batch 238 d_loss : 0.577789
# batch 238 g_loss : 1.210923
# batch 239 d_loss : 0.540792
# batch 239 g_loss : 1.078400
# batch 240 d_loss : 0.532693
# batch 240 g_loss : 1.332915
# batch 241 d_loss : 0.471776
# batch 241 g_loss : 1.108858
# batch 242 d_loss : 0.453001
# batch 242 g_loss : 1.447001
# batch 243 d_loss : 0.320474
# batch 243 g_loss : 1.702222
# batch 244 d_loss : 0.464629
# batch 244 g_loss : 1.770275
# batch 245 d_loss : 0.364530
# batch 245 g_loss : 1.732082
# batch 246 d_loss : 0.488554
# batch 246 g_loss : 1.619032
# batch 247 d_loss : 0.404223
# batch 247 g_loss : 1.522217
# batch 248 d_loss : 0.416257
# batch 248 g_loss : 1.681263
# batch 249 d_loss : 0.289699
# batch 249 g_loss : 2.041066
# batch 250 d_loss : 0.407538
# batch 250 g_loss : 1.672458
# batch 251 d_loss : 0.380541
# batch 251 g_loss : 1.883089
# batch 252 d_loss : 0.477594
# batch 252 g_loss : 1.702164
# batch 253 d_loss : 0.847215
# batch 253 g_loss : 1.172928
# batch 254 d_loss : 0.707187
# batch 254 g_loss : 1.259225
# batch 255 d_loss : 0.470996
# batch 255 g_loss : 1.459858
# batch 256 d_loss : 0.448073
# batch 256 g_loss : 1.667205
# batch 257 d_loss : 0.438654
# batch 257 g_loss : 1.182505
# batch 258 d_loss : 0.410278
# batch 258 g_loss : 1.640306
# batch 259 d_loss : 0.416649
# batch 259 g_loss : 1.205850
# batch 260 d_loss : 0.409236
# ...
# batch 314 g_loss : 2.542686
# batch 315 d_loss : 0.339796
# batch 315 g_loss : 2.926591
# batch 316 d_loss : 0.269525
# batch 316 g_loss : 2.883874
# batch 317 d_loss : 0.457261
# batch 317 g_loss : 2.692649
# batch 318 d_loss : 0.561289
# batch 318 g_loss : 2.067309
# batch 319 d_loss : 0.552509
# batch 319 g_loss : 2.264184
# batch 320 d_loss : 0.486597
# batch 320 g_loss : 1.857929
# batch 321 d_loss : 0.375358
# batch 321 g_loss : 2.800625
# batch 322 d_loss : 0.278862
# batch 322 g_loss : 2.179927
# batch 323 d_loss : 0.498963
# batch 323 g_loss : 1.417623
# batch 324 d_loss : 0.435978
# batch 324 g_loss : 2.795931
# batch 325 d_loss : 0.405638
# batch 325 g_loss : 1.457412
# batch 326 d_loss : 0.283783
# batch 326 g_loss : 2.505410
# batch 327 d_loss : 0.390672
# batch 327 g_loss : 1.583535
# batch 328 d_loss : 0.342674
# batch 328 g_loss : 2.241703
# batch 329 d_loss : 0.285649
# batch 329 g_loss : 2.495003
# batch 330 d_loss : 0.250566
# batch 330 g_loss : 2.513434
# batch 331 d_loss : 0.338830
# batch 331 g_loss : 1.704791
# batch 332 d_loss : 0.350968
# batch 332 g_loss : 2.747412
# batch 333 d_loss : 0.394695
# batch 333 g_loss : 1.502488
# batch 334 d_loss : 0.449448
# batch 334 g_loss : 2.095017
# batch 335 d_loss : 0.447181
# batch 335 g_loss : 1.364953
# batch 336 d_loss : 0.488128
# batch 336 g_loss : 1.663622
# batch 337 d_loss : 0.318095
# batch 337 g_loss : 2.049621
# batch 338 d_loss : 0.323653
# batch 338 g_loss : 1.634107
# batch 339 d_loss : 0.324344
# batch 339 g_loss : 2.481580
# batch 340 d_loss : 0.328099
# batch 340 g_loss : 1.657260
# batch 341 d_loss : 0.236095
# batch 341 g_loss : 2.481971
# batch 342 d_loss : 0.204087
# batch 342 g_loss : 2.477227
# batch 343 d_loss : 0.242063
# batch 343 g_loss : 1.912375
# batch 344 d_loss : 0.280151
# batch 344 g_loss : 2.324582
# batch 345 d_loss : 0.247655
# batch 345 g_loss : 2.063428
# batch 346 d_loss : 0.225948
# batch 346 g_loss : 2.182903
# batch 347 d_loss : 0.255316
# batch 347 g_loss : 2.299991
# batch 348 d_loss : 0.263477
# batch 348 g_loss : 2.288425
# batch 349 d_loss : 0.198705
# batch 349 g_loss : 2.363916
# batch 350 d_loss : 0.226187
# batch 350 g_loss : 2.957756
# batch 351 d_loss : 0.134179
# batch 351 g_loss : 3.235165
# batch 352 d_loss : 0.148496
# batch 352 g_loss : 2.621852
# batch 353 d_loss : 0.277611
# batch 353 g_loss : 1.938795
# batch 354 d_loss : 0.265389
# batch 354 g_loss : 2.236735
# batch 355 d_loss : 0.257488
# batch 355 g_loss : 2.275340
# batch 356 d_loss : 0.255580
# batch 356 g_loss : 2.555148
# batch 357 d_loss : 0.383632
# batch 357 g_loss : 2.275300
# batch 358 d_loss : 0.403518
# batch 358 g_loss : 3.084298
# batch 359 d_loss : 0.331927
# batch 359 g_loss : 2.346195
# batch 360 d_loss : 0.259942
# batch 360 g_loss : 2.382822
# batch 361 d_loss : 0.539109
# batch 361 g_loss : 1.824839
# batch 362 d_loss : 0.525525
# batch 362 g_loss : 1.581110
# batch 363 d_loss : 0.435134
# batch 363 g_loss : 2.555074
# batch 364 d_loss : 0.390475
# batch 364 g_loss : 1.946333
# batch 365 d_loss : 0.438866
# batch 365 g_loss : 2.604003
# batch 366 d_loss : 0.392227
# batch 366 g_loss : 1.769825
# batch 367 d_loss : 0.401226
# batch 367 g_loss : 3.236670
# batch 368 d_loss : 0.363244
# batch 368 g_loss : 1.824505
# batch 369 d_loss : 0.318159
# batch 369 g_loss : 2.110439
# batch 370 d_loss : 0.295463
# batch 370 g_loss : 2.370427
# batch 371 d_loss : 0.295037
# batch 371 g_loss : 2.194693
# batch 372 d_loss : 0.253278
# batch 372 g_loss : 2.860417
# batch 373 d_loss : 0.231289
# batch 373 g_loss : 2.193339
# batch 374 d_loss : 0.259755
# batch 374 g_loss : 2.060122
# batch 375 d_loss : 0.288762
# batch 375 g_loss : 1.601539
# batch 376 d_loss : 0.401539
# batch 376 g_loss : 1.678124
# batch 377 d_loss : 0.381646
# batch 377 g_loss : 2.344224
# batch 378 d_loss : 0.278727
# batch 378 g_loss : 1.923412
# batch 379 d_loss : 0.323177
# batch 379 g_loss : 1.690395
# batch 380 d_loss : 0.362125
# batch 380 g_loss : 1.585141
# batch 381 d_loss : 0.374273
# batch 381 g_loss : 1.616390
# batch 382 d_loss : 0.391448
# batch 382 g_loss : 2.036814
# batch 383 d_loss : 0.321371
# batch 383 g_loss : 1.893788
# batch 384 d_loss : 0.328876
# batch 384 g_loss : 1.756652
# batch 385 d_loss : 0.311174
# batch 385 g_loss : 1.606910
# batch 386 d_loss : 0.250410
# batch 386 g_loss : 2.144866
# batch 387 d_loss : 0.258726
# batch 387 g_loss : 1.919273
# batch 388 d_loss : 0.272570
# batch 388 g_loss : 2.027051
# batch 389 d_loss : 0.222390
# batch 389 g_loss : 2.418450
# batch 390 d_loss : 0.297968
# batch 390 g_loss : 2.326623
# batch 391 d_loss : 0.347163
# batch 391 g_loss : 1.612753
# batch 392 d_loss : 0.346563
# batch 392 g_loss : 2.334111
# batch 393 d_loss : 0.321908
# batch 393 g_loss : 2.029779
# batch 394 d_loss : 0.276844
# batch 394 g_loss : 2.123121
# batch 395 d_loss : 0.382927
# batch 395 g_loss : 1.883255
# batch 396 d_loss : 0.339358
# batch 396 g_loss : 1.756309
# batch 397 d_loss : 0.274707
# batch 397 g_loss : 2.981837
# batch 398 d_loss : 0.314745
# batch 398 g_loss : 2.490211
# batch 399 d_loss : 0.337847
# batch 399 g_loss : 1.469566
# batch 400 d_loss : 0.365818
# batch 400 g_loss : 2.317089
# batch 401 d_loss : 0.376795
# batch 401 g_loss : 1.812612
# batch 402 d_loss : 0.344219
# batch 402 g_loss : 2.992567
# batch 403 d_loss : 0.388637
# batch 403 g_loss : 2.356376
# batch 404 d_loss : 0.331764
# batch 404 g_loss : 2.033256
# batch 405 d_loss : 0.312868
# batch 405 g_loss : 1.891585
# batch 406 d_loss : 0.344592
# batch 406 g_loss : 2.563381
# batch 407 d_loss : 0.300015
# batch 407 g_loss : 2.240142
# batch 408 d_loss : 0.341937
# batch 408 g_loss : 1.872320
# batch 409 d_loss : 0.412648
# batch 409 g_loss : 2.305235
# batch 410 d_loss : 0.301640
# batch 410 g_loss : 1.794734
# batch 411 d_loss : 0.270207
# batch 411 g_loss : 2.570757
# batch 412 d_loss : 0.364806
# batch 412 g_loss : 1.735403
# batch 413 d_loss : 0.285601
# batch 413 g_loss : 2.593201
# batch 414 d_loss : 0.292317
# batch 414 g_loss : 1.939266
# batch 415 d_loss : 0.358078
# batch 415 g_loss : 1.728178
# batch 416 d_loss : 0.298947
# batch 416 g_loss : 1.691084
# batch 417 d_loss : 0.352660
# batch 417 g_loss : 2.990895
# batch 418 d_loss : 0.371261
# batch 418 g_loss : 1.482788
# batch 419 d_loss : 0.317251
# batch 419 g_loss : 1.979895
# batch 420 d_loss : 0.336486
# batch 420 g_loss : 1.707642
# batch 421 d_loss : 0.298578
# batch 421 g_loss : 2.165473
# batch 422 d_loss : 0.314093
# batch 422 g_loss : 1.310323
# batch 423 d_loss : 0.308797
# batch 423 g_loss : 1.971588
# batch 424 d_loss : 0.422791
# batch 424 g_loss : 1.604072
# batch 425 d_loss : 0.353677
# batch 425 g_loss : 2.196936
# batch 426 d_loss : 0.362267
# batch 426 g_loss : 1.615532
# batch 427 d_loss : 0.377949
# batch 427 g_loss : 1.704603
# batch 428 d_loss : 0.335178
# batch 428 g_loss : 2.138728
# batch 429 d_loss : 0.281516
# batch 429 g_loss : 1.977687
# batch 430 d_loss : 0.346024
# batch 430 g_loss : 1.445905
# batch 431 d_loss : 0.300112
# batch 431 g_loss : 1.978474
# batch 432 d_loss : 0.309318
# batch 432 g_loss : 2.203134
# batch 433 d_loss : 0.308133
# batch 433 g_loss : 1.682862
# batch 434 d_loss : 0.341793
# batch 434 g_loss : 1.681663
# batch 435 d_loss : 0.248478
# batch 435 g_loss : 2.223037
# batch 436 d_loss : 0.306544
# batch 436 g_loss : 1.769255
# batch 437 d_loss : 0.329244
# batch 437 g_loss : 1.559155
# batch 438 d_loss : 0.264347
# batch 438 g_loss : 2.297575
# batch 439 d_loss : 0.261619
# batch 439 g_loss : 2.090266
# batch 440 d_loss : 0.262031
# batch 440 g_loss : 2.121679
# batch 441 d_loss : 0.230317
# batch 441 g_loss : 2.493141
# batch 442 d_loss : 0.335795
# batch 442 g_loss : 1.717564
# batch 443 d_loss : 0.356895
# batch 443 g_loss : 2.518753
# batch 444 d_loss : 0.278856
# batch 444 g_loss : 1.685443
# batch 445 d_loss : 0.270749
# batch 445 g_loss : 1.850208
# batch 446 d_loss : 0.309874
# batch 446 g_loss : 2.371177
# batch 447 d_loss : 0.318925
# batch 447 g_loss : 2.542608
# batch 448 d_loss : 0.310202
# batch 448 g_loss : 1.721791
# batch 449 d_loss : 0.316483
# batch 449 g_loss : 2.044450
# batch 450 d_loss : 0.386809
# batch 450 g_loss : 1.610819
# batch 451 d_loss : 0.343567
# batch 451 g_loss : 2.192877
# batch 452 d_loss : 0.382669
# batch 452 g_loss : 2.405128
# batch 453 d_loss : 0.281111
# batch 453 g_loss : 2.344516
# batch 454 d_loss : 0.230458
# batch 454 g_loss : 2.543018
# batch 455 d_loss : 0.288369
# batch 455 g_loss : 1.918780
# batch 456 d_loss : 0.338999
# batch 456 g_loss : 2.601384
# batch 457 d_loss : 0.415249
# batch 457 g_loss : 1.471140
# batch 458 d_loss : 0.294565
# batch 458 g_loss : 2.684066
# batch 459 d_loss : 0.376703
# batch 459 g_loss : 1.623485
# batch 460 d_loss : 0.311788
# batch 460 g_loss : 2.742305
# batch 461 d_loss : 0.329835
# batch 461 g_loss : 1.734013
# batch 462 d_loss : 0.261191
# batch 462 g_loss : 2.201000
# batch 463 d_loss : 0.243364
# batch 463 g_loss : 2.335574
# batch 464 d_loss : 0.368986
# batch 464 g_loss : 1.335367
# batch 465 d_loss : 0.365035
# batch 465 g_loss : 2.728375
# batch 466 d_loss : 0.363842
# batch 466 g_loss : 1.141590
# batch 467 d_loss : 0.411397
# batch 467 g_loss : 3.439999
# batch 468 d_loss : 0.438263
# batch 468 g_loss : 1.580709
# batch 469 d_loss : 0.308079
# batch 469 g_loss : 1.864884
# batch 470 d_loss : 0.287199
# batch 470 g_loss : 2.180311
# batch 471 d_loss : 0.295471
# batch 471 g_loss : 1.897252
# batch 472 d_loss : 0.374810
# batch 472 g_loss : 1.657256
# batch 473 d_loss : 0.380216
# batch 473 g_loss : 1.875460
# batch 474 d_loss : 0.307317
# batch 474 g_loss : 1.765404
# batch 475 d_loss : 0.354309
# batch 475 g_loss : 1.581841
# batch 476 d_loss : 0.306210
# batch 476 g_loss : 2.109944
# batch 477 d_loss : 0.391991
# batch 477 g_loss : 1.481461
# batch 478 d_loss : 0.344760
# batch 478 g_loss : 2.598336
# batch 479 d_loss : 0.416156
# batch 479 g_loss : 1.310502
# batch 480 d_loss : 0.364585
# batch 480 g_loss : 1.989406
# batch 481 d_loss : 0.369233
# batch 481 g_loss : 1.376673
# batch 482 d_loss : 0.368467
# batch 482 g_loss : 2.341209
# batch 483 d_loss : 0.293426
# batch 483 g_loss : 1.543383
# batch 484 d_loss : 0.310290
# batch 484 g_loss : 1.836559
# batch 485 d_loss : 0.276601
# batch 485 g_loss : 1.692861
# batch 486 d_loss : 0.332305
# batch 486 g_loss : 1.919629
# batch 487 d_loss : 0.310261
# batch 487 g_loss : 1.381341
# batch 488 d_loss : 0.291845
# batch 488 g_loss : 2.164986
# batch 489 d_loss : 0.212572
# batch 489 g_loss : 2.427014
# batch 490 d_loss : 0.191823
# batch 490 g_loss : 2.598531
# batch 491 d_loss : 0.264456
# batch 491 g_loss : 1.996186
# batch 492 d_loss : 0.213627
# batch 492 g_loss : 2.314417
# batch 493 d_loss : 0.236271
# batch 493 g_loss : 2.026920
# batch 494 d_loss : 0.220951
# batch 494 g_loss : 2.661568
# batch 495 d_loss : 0.235560
# batch 495 g_loss : 2.581497
# batch 496 d_loss : 0.216091
# batch 496 g_loss : 2.716332
# batch 497 d_loss : 0.290111
# batch 497 g_loss : 2.893854
# batch 498 d_loss : 0.306853
# batch 498 g_loss : 2.012051
# batch 499 d_loss : 0.362063
# batch 499 g_loss : 2.222628
# batch 500 d_loss : 0.344936
# batch 500 g_loss : 2.075874
# batch 501 d_loss : 0.392387
# batch 501 g_loss : 2.569138
# batch 502 d_loss : 0.416234
# batch 502 g_loss : 2.588370
# batch 503 d_loss : 0.469827
# batch 503 g_loss : 2.153330
# batch 504 d_loss : 0.499755
# batch 504 g_loss : 1.924141
# batch 505 d_loss : 0.392430
# batch 505 g_loss : 2.794919
# batch 506 d_loss : 0.371816
# batch 506 g_loss : 2.231699
# batch 507 d_loss : 0.507542
# batch 507 g_loss : 1.602686
# batch 508 d_loss : 0.471324
# batch 508 g_loss : 2.104969
# batch 509 d_loss : 0.376612
# batch 509 g_loss : 2.796551
# batch 510 d_loss : 0.371173
# batch 510 g_loss : 2.240725
# batch 511 d_loss : 0.352363
# batch 511 g_loss : 2.632644
# batch 512 d_loss : 0.331298
# batch 512 g_loss : 1.996215
# batch 513 d_loss : 0.260450
# batch 513 g_loss : 2.090961
# batch 514 d_loss : 0.320882
# batch 514 g_loss : 3.052731
# batch 515 d_loss : 0.310237
# batch 515 g_loss : 2.121265
# batch 516 d_loss : 0.243669
# batch 516 g_loss : 2.701921
# batch 517 d_loss : 0.396409
# batch 517 g_loss : 1.434189
# batch 518 d_loss : 0.392281
# batch 518 g_loss : 2.255743
# batch 519 d_loss : 0.437361
# batch 519 g_loss : 1.090739
# batch 520 d_loss : 0.563737
# batch 520 g_loss : 2.749175
# batch 521 d_loss : 0.380882
# batch 521 g_loss : 1.170163
# batch 522 d_loss : 0.324962
# batch 522 g_loss : 1.774874
# batch 523 d_loss : 0.308033
# batch 523 g_loss : 2.202644
# batch 524 d_loss : 0.330705
# batch 524 g_loss : 1.603620
# batch 525 d_loss : 0.316627
# batch 525 g_loss : 2.201018
# batch 526 d_loss : 0.344171
# batch 526 g_loss : 1.995765
# batch 527 d_loss : 0.245362
# batch 527 g_loss : 2.244036
# batch 528 d_loss : 0.329324
# batch 528 g_loss : 1.700235
# batch 529 d_loss : 0.282920
# batch 529 g_loss : 1.764993
# batch 530 d_loss : 0.306956
# batch 530 g_loss : 2.390565
# batch 531 d_loss : 0.249472
# batch 531 g_loss : 2.603066
# batch 532 d_loss : 0.232616
# batch 532 g_loss : 2.346336
# batch 533 d_loss : 0.242245
# batch 533 g_loss : 2.344019
# batch 534 d_loss : 0.233639
# batch 534 g_loss : 2.485299
# batch 535 d_loss : 0.195386
# batch 535 g_loss : 2.312307
# batch 536 d_loss : 0.204934
# batch 536 g_loss : 2.874254
# batch 537 d_loss : 0.206530
# batch 537 g_loss : 2.401711
# batch 538 d_loss : 0.199105
# batch 538 g_loss : 2.172788
# batch 539 d_loss : 0.219555
# batch 539 g_loss : 2.592397
# batch 540 d_loss : 0.303964
# batch 540 g_loss : 2.616137
# batch 541 d_loss : 0.317247
# batch 541 g_loss : 2.150238
# batch 542 d_loss : 0.265587
# batch 542 g_loss : 2.513157
# batch 543 d_loss : 0.400826
# batch 543 g_loss : 2.157748
# batch 544 d_loss : 0.382976
# batch 544 g_loss : 1.568360
# batch 545 d_loss : 0.412987
# batch 545 g_loss : 2.824809
# batch 546 d_loss : 0.452957
# batch 546 g_loss : 1.195106
# batch 547 d_loss : 0.628383
# batch 547 g_loss : 2.785190
# batch 548 d_loss : 0.363236
# batch 548 g_loss : 1.884243
# batch 549 d_loss : 0.298758
# batch 549 g_loss : 2.571103
# batch 550 d_loss : 0.350189
# batch 550 g_loss : 2.115355
# batch 551 d_loss : 0.344590
# batch 551 g_loss : 2.066852
# batch 552 d_loss : 0.382327
# batch 552 g_loss : 2.313081
# batch 553 d_loss : 0.332691
# batch 553 g_loss : 1.949936
# batch 554 d_loss : 0.281050
# batch 554 g_loss : 2.237487
# batch 555 d_loss : 0.338083
# batch 555 g_loss : 1.664199
# batch 556 d_loss : 0.347302
# batch 556 g_loss : 2.256839
# batch 557 d_loss : 0.291529
# batch 557 g_loss : 1.995364
# batch 558 d_loss : 0.231991
# batch 558 g_loss : 2.239400
# batch 559 d_loss : 0.264641
# batch 559 g_loss : 1.928712
# batch 560 d_loss : 0.275700
# batch 560 g_loss : 2.253597
# batch 561 d_loss : 0.281583
# batch 561 g_loss : 1.829498
# batch 562 d_loss : 0.345519
# batch 562 g_loss : 2.321695
# batch 563 d_loss : 0.424258
# batch 563 g_loss : 1.446842
# batch 564 d_loss : 0.407748
# batch 564 g_loss : 1.770041
# batch 565 d_loss : 0.380739
# batch 565 g_loss : 1.528870
# batch 566 d_loss : 0.367922
# batch 566 g_loss : 1.789396
# batch 567 d_loss : 0.333762
# batch 567 g_loss : 1.973325
# batch 568 d_loss : 0.262232
# batch 568 g_loss : 1.775830
# batch 569 d_loss : 0.329349
# batch 569 g_loss : 2.033956
# batch 570 d_loss : 0.530339
# batch 570 g_loss : 1.337637
# batch 571 d_loss : 0.343463
# batch 571 g_loss : 2.644580
# batch 572 d_loss : 0.301384
# batch 572 g_loss : 1.414615
# batch 573 d_loss : 0.347189
# batch 573 g_loss : 2.059894
# batch 574 d_loss : 0.302477
# batch 574 g_loss : 1.471434
# batch 575 d_loss : 0.273404
# batch 575 g_loss : 2.419640
# batch 576 d_loss : 0.288518
# batch 576 g_loss : 1.792213
# batch 577 d_loss : 0.307032
# batch 577 g_loss : 1.723485
# batch 578 d_loss : 0.261667
# batch 578 g_loss : 2.717609
# batch 579 d_loss : 0.406869
# batch 579 g_loss : 1.696615
# batch 580 d_loss : 0.302200
# batch 580 g_loss : 1.812109
# batch 581 d_loss : 0.292065
# batch 581 g_loss : 2.439207
# batch 582 d_loss : 0.233664
# batch 582 g_loss : 2.653749
# batch 583 d_loss : 0.262405
# batch 583 g_loss : 1.715812
# batch 584 d_loss : 0.353037
# batch 584 g_loss : 1.929841
# batch 585 d_loss : 0.290078
# batch 585 g_loss : 2.340127
# batch 586 d_loss : 0.271863
# batch 586 g_loss : 2.406529
# batch 587 d_loss : 0.148032
# batch 587 g_loss : 3.409158
# batch 588 d_loss : 0.353547
# batch 588 g_loss : 1.750957
# batch 589 d_loss : 0.335379
# batch 589 g_loss : 2.701838
# batch 590 d_loss : 0.215511
# batch 590 g_loss : 2.255093
# batch 591 d_loss : 0.207149
# batch 591 g_loss : 2.250840
# batch 592 d_loss : 0.261928
# batch 592 g_loss : 1.460019
# batch 593 d_loss : 0.695018
# batch 593 g_loss : 2.433069
# batch 594 d_loss : 0.712020
# batch 594 g_loss : 1.256742
# batch 595 d_loss : 0.519309
# batch 595 g_loss : 3.775999
# batch 596 d_loss : 0.438334
# batch 596 g_loss : 2.064436
# batch 597 d_loss : 0.382721
# batch 597 g_loss : 1.943406
# batch 598 d_loss : 0.435794
# batch 598 g_loss : 2.285796
# batch 599 d_loss : 0.284132
# batch 599 g_loss : 2.668193

# %%
generate(32)
# Out:
# B:\Anaconda3\envs\tensorflow\lib\site-packages\ipykernel_launcher.py:5: UserWarning: Update your `Dense` call to the Keras 2 API: `Dense(input_dim=100, units=1024)`
#   """
